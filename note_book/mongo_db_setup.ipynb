# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\kumar\OneDrive - Edunet Foundation\Documents\Cardeo_vasular.csv")

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
data=df.to_dict(orient='records')
data
# Out:
# [{'id': 0,
#   'age': 64,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 221.0,
#   'sysBP': 148.0,
#   'diaBP': 85.0,
#   'BMI': nan,
#   'heartRate': 90.0,
#   'glucose': 80.0,
#   'TenYearCHD': 1},
#  {'id': 1,
#   'age': 36,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 212.0,
#   'sysBP': 168.0,
#   'diaBP': 98.0,
#   'BMI': 29.77,
#   'heartRate': 72.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 2,
#   'age': 46,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 250.0,
#   'sysBP': 116.0,
#   'diaBP': 71.0,
#   'BMI': 20.35,
#   'heartRate': 88.0,
#   'glucose': 94.0,
#   'TenYearCHD': 0},
#  {'id': 3,
#   'age': 50,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 233.0,
#   'sysBP': 158.0,
#   'diaBP': 88.0,
#   'BMI': 28.26,
#   'heartRate': 68.0,
#   'glucose': 94.0,
#   'TenYearCHD': 1},
#  {'id': 4,
#   'age': 64,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 241.0,
#   'sysBP': 136.5,
#   'diaBP': 85.0,
#   'BMI': 26.42,
#   'heartRate': 70.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 5,
#   'age': 61,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 272.0,
#   'sysBP': 182.0,
#   'diaBP': 121.0,
#   'BMI': 32.8,
#   'heartRate': 85.0,
#   'glucose': 65.0,
#   'TenYearCHD': 1},
#  {'id': 6,
#   'age': 61,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 238.0,
#   'sysBP': 232.0,
#   'diaBP': 136.0,
#   'BMI': 24.83,
#   'heartRate': 75.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 7,
#   'age': 36,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 35.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 295.0,
#   'sysBP': 102.0,
#   'diaBP': 68.0,
#   'BMI': 28.15,
#   'heartRate': 60.0,
#   'glucose': 63.0,
#   'TenYearCHD': 0},
#  {'id': 8,
#   'age': 41,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': nan,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 220.0,
#   'sysBP': 126.0,
#   'diaBP': 78.0,
#   'BMI': 20.7,
#   'heartRate': 86.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 9,
#   'age': 55,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 326.0,
#   'sysBP': 144.0,
#   'diaBP': 81.0,
#   'BMI': 25.71,
#   'heartRate': 85.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 10,
#   'age': 61,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': nan,
#   'sysBP': 185.0,
#   'diaBP': 121.0,
#   'BMI': 35.22,
#   'heartRate': 80.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 11,
#   'age': 53,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 210.0,
#   'sysBP': 138.0,
#   'diaBP': 86.5,
#   'BMI': 22.49,
#   'heartRate': 88.0,
#   'glucose': 87.0,
#   'TenYearCHD': 0},
#  {'id': 12,
#   'age': 43,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 213.0,
#   'sysBP': 96.0,
#   'diaBP': 62.0,
#   'BMI': 19.38,
#   'heartRate': 74.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 13,
#   'age': 44,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 40.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 227.0,
#   'sysBP': 146.5,
#   'diaBP': 97.0,
#   'BMI': 26.92,
#   'heartRate': 80.0,
#   'glucose': 67.0,
#   'TenYearCHD': 0},
#  {'id': 14,
#   'age': 58,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 188.0,
#   'sysBP': 160.0,
#   'diaBP': 120.0,
#   'BMI': 35.58,
#   'heartRate': 88.0,
#   'glucose': 85.0,
#   'TenYearCHD': 0},
#  {'id': 15,
#   'age': 51,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 212.0,
#   'sysBP': 146.0,
#   'diaBP': 89.0,
#   'BMI': 24.49,
#   'heartRate': 100.0,
#   'glucose': 132.0,
#   'TenYearCHD': 1},
#  {'id': 16,
#   'age': 50,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 240.0,
#   'sysBP': 163.0,
#   'diaBP': 105.0,
#   'BMI': 31.37,
#   'heartRate': 89.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 17,
#   'age': 44,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 257.0,
#   'sysBP': 129.0,
#   'diaBP': 93.0,
#   'BMI': 27.56,
#   'heartRate': 75.0,
#   'glucose': 76.0,
#   'TenYearCHD': 0},
#  {'id': 18,
#   'age': 56,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 267.0,
#   'sysBP': 122.5,
#   'diaBP': 85.0,
#   'BMI': 24.22,
#   'heartRate': 92.0,
#   'glucose': 100.0,
#   'TenYearCHD': 0},
#  {'id': 19,
#   'age': 42,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 130.0,
#   'diaBP': 91.0,
#   'BMI': 25.77,
#   'heartRate': 72.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 20,
#   'age': 42,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 199.0,
#   'sysBP': 141.0,
#   'diaBP': 92.0,
#   'BMI': 43.69,
#   'heartRate': 80.0,
#   'glucose': 60.0,
#   'TenYearCHD': 1},
#  {'id': 21,
#   'age': 38,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 175.0,
#   'sysBP': 142.0,
#   'diaBP': 86.0,
#   'BMI': 22.01,
#   'heartRate': 82.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 22,
#   'age': 38,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 164.0,
#   'sysBP': 113.0,
#   'diaBP': 68.0,
#   'BMI': 25.75,
#   'heartRate': 70.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 23,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 226.0,
#   'sysBP': 172.5,
#   'diaBP': 98.0,
#   'BMI': 26.47,
#   'heartRate': 87.0,
#   'glucose': 81.0,
#   'TenYearCHD': 0},
#  {'id': 24,
#   'age': 35,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 248.0,
#   'sysBP': 107.0,
#   'diaBP': 73.0,
#   'BMI': 20.64,
#   'heartRate': 90.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 25,
#   'age': 44,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 220.0,
#   'sysBP': 105.0,
#   'diaBP': 70.0,
#   'BMI': 21.01,
#   'heartRate': 58.0,
#   'glucose': 68.0,
#   'TenYearCHD': 0},
#  {'id': 26,
#   'age': 36,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 245.0,
#   'sysBP': 122.0,
#   'diaBP': 74.5,
#   'BMI': 24.27,
#   'heartRate': 79.0,
#   'glucose': 85.0,
#   'TenYearCHD': 0},
#  {'id': 27,
#   'age': 54,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 279.0,
#   'sysBP': 155.0,
#   'diaBP': 105.0,
#   'BMI': 26.47,
#   'heartRate': 78.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 28,
#   'age': 41,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 245.0,
#   'sysBP': 134.0,
#   'diaBP': 98.0,
#   'BMI': 24.26,
#   'heartRate': 85.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 29,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 1,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 273.0,
#   'sysBP': 152.0,
#   'diaBP': 70.0,
#   'BMI': 19.69,
#   'heartRate': 80.0,
#   'glucose': 79.0,
#   'TenYearCHD': 1},
#  {'id': 30,
#   'age': 51,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 227.0,
#   'sysBP': 158.0,
#   'diaBP': 105.0,
#   'BMI': 27.22,
#   'heartRate': 60.0,
#   'glucose': 96.0,
#   'TenYearCHD': 1},
#  {'id': 31,
#   'age': 55,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 252.0,
#   'sysBP': 129.0,
#   'diaBP': 84.0,
#   'BMI': 23.55,
#   'heartRate': 80.0,
#   'glucose': 72.0,
#   'TenYearCHD': 0},
#  {'id': 32,
#   'age': 51,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 198.0,
#   'sysBP': 142.5,
#   'diaBP': 80.0,
#   'BMI': 23.86,
#   'heartRate': 76.0,
#   'glucose': 100.0,
#   'TenYearCHD': 0},
#  {'id': 33,
#   'age': 38,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 266.0,
#   'sysBP': 149.0,
#   'diaBP': 91.0,
#   'BMI': 31.08,
#   'heartRate': 69.0,
#   'glucose': 61.0,
#   'TenYearCHD': 0},
#  {'id': 34,
#   'age': 62,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 216.0,
#   'sysBP': 126.0,
#   'diaBP': 82.0,
#   'BMI': 21.18,
#   'heartRate': 69.0,
#   'glucose': 69.0,
#   'TenYearCHD': 0},
#  {'id': 35,
#   'age': 47,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 237.0,
#   'sysBP': 130.0,
#   'diaBP': 78.0,
#   'BMI': 19.66,
#   'heartRate': 80.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 36,
#   'age': 46,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 193.0,
#   'sysBP': 106.5,
#   'diaBP': 70.5,
#   'BMI': 26.18,
#   'heartRate': 75.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 37,
#   'age': 63,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 293.0,
#   'sysBP': 186.5,
#   'diaBP': 97.0,
#   'BMI': 30.47,
#   'heartRate': 60.0,
#   'glucose': 96.0,
#   'TenYearCHD': 0},
#  {'id': 38,
#   'age': 41,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 9.0,
#   'BPMeds': 1.0,
#   'prevalentStroke': 1,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 180.0,
#   'sysBP': 114.0,
#   'diaBP': 70.0,
#   'BMI': 22.41,
#   'heartRate': 92.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 39,
#   'age': 43,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 237.0,
#   'sysBP': 104.0,
#   'diaBP': 74.0,
#   'BMI': 23.02,
#   'heartRate': 60.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 40,
#   'age': 34,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 206.0,
#   'sysBP': 101.0,
#   'diaBP': 63.0,
#   'BMI': 21.5,
#   'heartRate': 75.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 41,
#   'age': 51,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 199.0,
#   'sysBP': 113.0,
#   'diaBP': 68.0,
#   'BMI': 22.46,
#   'heartRate': 58.0,
#   'glucose': 68.0,
#   'TenYearCHD': 0},
#  {'id': 42,
#   'age': 39,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 60.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 215.0,
#   'sysBP': 112.0,
#   'diaBP': 65.0,
#   'BMI': 23.6,
#   'heartRate': 59.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 43,
#   'age': 46,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 208.0,
#   'sysBP': 122.0,
#   'diaBP': 76.0,
#   'BMI': 18.4,
#   'heartRate': 75.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 44,
#   'age': 51,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 262.0,
#   'sysBP': 102.0,
#   'diaBP': 64.0,
#   'BMI': 28.06,
#   'heartRate': 80.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 45,
#   'age': 64,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 270.0,
#   'sysBP': 142.0,
#   'diaBP': 68.0,
#   'BMI': 21.32,
#   'heartRate': 76.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 46,
#   'age': 55,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 293.0,
#   'sysBP': 165.0,
#   'diaBP': 106.0,
#   'BMI': 24.71,
#   'heartRate': 90.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 47,
#   'age': 59,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 292.0,
#   'sysBP': 114.0,
#   'diaBP': 84.0,
#   'BMI': 27.39,
#   'heartRate': 68.0,
#   'glucose': 72.0,
#   'TenYearCHD': 0},
#  {'id': 48,
#   'age': 55,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 346.0,
#   'sysBP': 131.0,
#   'diaBP': 81.0,
#   'BMI': 22.69,
#   'heartRate': 75.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 49,
#   'age': 46,
#   'education': nan,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 212.0,
#   'sysBP': 122.5,
#   'diaBP': 75.5,
#   'BMI': 23.51,
#   'heartRate': 67.0,
#   'glucose': 103.0,
#   'TenYearCHD': 0},
#  {'id': 50,
#   'age': 62,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 202.0,
#   'sysBP': 111.0,
#   'diaBP': 79.5,
#   'BMI': 27.91,
#   'heartRate': 80.0,
#   'glucose': 100.0,
#   'TenYearCHD': 0},
#  {'id': 51,
#   'age': 56,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 340.0,
#   'sysBP': 134.0,
#   'diaBP': 89.5,
#   'BMI': 21.91,
#   'heartRate': 50.0,
#   'glucose': 72.0,
#   'TenYearCHD': 1},
#  {'id': 52,
#   'age': 45,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 262.0,
#   'sysBP': 133.0,
#   'diaBP': 83.0,
#   'BMI': 22.19,
#   'heartRate': 76.0,
#   'glucose': 92.0,
#   'TenYearCHD': 1},
#  {'id': 53,
#   'age': 44,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 334.0,
#   'sysBP': 131.0,
#   'diaBP': 74.0,
#   'BMI': 28.82,
#   'heartRate': 80.0,
#   'glucose': 77.0,
#   'TenYearCHD': 1},
#  {'id': 54,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 1,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 213.0,
#   'sysBP': 163.0,
#   'diaBP': 94.0,
#   'BMI': nan,
#   'heartRate': 76.0,
#   'glucose': 69.0,
#   'TenYearCHD': 1},
#  {'id': 55,
#   'age': 51,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 351.0,
#   'sysBP': 134.0,
#   'diaBP': 97.5,
#   'BMI': 21.66,
#   'heartRate': 100.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 56,
#   'age': 49,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 9.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 235.0,
#   'sysBP': 109.0,
#   'diaBP': 70.0,
#   'BMI': 28.66,
#   'heartRate': 74.0,
#   'glucose': 73.0,
#   'TenYearCHD': 1},
#  {'id': 57,
#   'age': 55,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 243.0,
#   'sysBP': 142.0,
#   'diaBP': 92.0,
#   'BMI': 30.24,
#   'heartRate': 70.0,
#   'glucose': 85.0,
#   'TenYearCHD': 0},
#  {'id': 58,
#   'age': 46,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 196.0,
#   'sysBP': 114.0,
#   'diaBP': 75.0,
#   'BMI': 21.01,
#   'heartRate': 60.0,
#   'glucose': 69.0,
#   'TenYearCHD': 0},
#  {'id': 59,
#   'age': 60,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 275.0,
#   'sysBP': 141.0,
#   'diaBP': 84.0,
#   'BMI': 29.66,
#   'heartRate': 75.0,
#   'glucose': 105.0,
#   'TenYearCHD': 0},
#  {'id': 60,
#   'age': 38,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 186.0,
#   'sysBP': 105.0,
#   'diaBP': 57.0,
#   'BMI': 21.1,
#   'heartRate': 85.0,
#   'glucose': 68.0,
#   'TenYearCHD': 0},
#  {'id': 61,
#   'age': 40,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 190.0,
#   'sysBP': 121.5,
#   'diaBP': 74.5,
#   'BMI': 29.35,
#   'heartRate': 73.0,
#   'glucose': 93.0,
#   'TenYearCHD': 0},
#  {'id': 62,
#   'age': 52,
#   'education': nan,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 268.0,
#   'sysBP': 109.0,
#   'diaBP': 70.0,
#   'BMI': 23.74,
#   'heartRate': 75.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 63,
#   'age': 48,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 234.0,
#   'sysBP': 144.0,
#   'diaBP': 90.0,
#   'BMI': 29.34,
#   'heartRate': 72.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 64,
#   'age': 62,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 264.0,
#   'sysBP': 129.0,
#   'diaBP': 85.0,
#   'BMI': 26.15,
#   'heartRate': 73.0,
#   'glucose': 63.0,
#   'TenYearCHD': 0},
#  {'id': 65,
#   'age': 37,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 156.0,
#   'sysBP': 120.0,
#   'diaBP': 87.0,
#   'BMI': 21.8,
#   'heartRate': 66.0,
#   'glucose': 89.0,
#   'TenYearCHD': 0},
#  {'id': 66,
#   'age': 60,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 260.0,
#   'sysBP': 178.0,
#   'diaBP': 103.0,
#   'BMI': 24.62,
#   'heartRate': 72.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 67,
#   'age': 60,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 225.0,
#   'sysBP': 149.0,
#   'diaBP': 96.0,
#   'BMI': 27.73,
#   'heartRate': 80.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 68,
#   'age': 61,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 183.0,
#   'sysBP': 150.0,
#   'diaBP': 86.0,
#   'BMI': 25.05,
#   'heartRate': 66.0,
#   'glucose': 70.0,
#   'TenYearCHD': 1},
#  {'id': 69,
#   'age': 65,
#   'education': nan,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': nan,
#   'sysBP': 152.5,
#   'diaBP': 97.5,
#   'BMI': 28.35,
#   'heartRate': 65.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 70,
#   'age': 50,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 210.0,
#   'sysBP': 121.5,
#   'diaBP': 78.0,
#   'BMI': 26.29,
#   'heartRate': 88.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 71,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 246.0,
#   'sysBP': 193.0,
#   'diaBP': 104.0,
#   'BMI': 23.08,
#   'heartRate': 80.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 72,
#   'age': 42,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 237.0,
#   'sysBP': 105.0,
#   'diaBP': 75.0,
#   'BMI': 23.85,
#   'heartRate': 70.0,
#   'glucose': 87.0,
#   'TenYearCHD': 0},
#  {'id': 73,
#   'age': 58,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 268.0,
#   'sysBP': 151.0,
#   'diaBP': 98.0,
#   'BMI': 20.34,
#   'heartRate': 72.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 74,
#   'age': 36,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 174.0,
#   'sysBP': 131.0,
#   'diaBP': 86.0,
#   'BMI': 26.23,
#   'heartRate': 75.0,
#   'glucose': 64.0,
#   'TenYearCHD': 0},
#  {'id': 75,
#   'age': 62,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 288.0,
#   'sysBP': 118.5,
#   'diaBP': 71.0,
#   'BMI': 26.18,
#   'heartRate': 68.0,
#   'glucose': 87.0,
#   'TenYearCHD': 0},
#  {'id': 76,
#   'age': 37,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 60.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 254.0,
#   'sysBP': 122.5,
#   'diaBP': 82.5,
#   'BMI': 23.87,
#   'heartRate': 88.0,
#   'glucose': 83.0,
#   'TenYearCHD': 0},
#  {'id': 77,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 1,
#   'totChol': 150.0,
#   'sysBP': 152.0,
#   'diaBP': 88.0,
#   'BMI': 36.54,
#   'heartRate': 72.0,
#   'glucose': 170.0,
#   'TenYearCHD': 0},
#  {'id': 78,
#   'age': 52,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 155.0,
#   'diaBP': 80.5,
#   'BMI': 29.6,
#   'heartRate': 72.0,
#   'glucose': 67.0,
#   'TenYearCHD': 0},
#  {'id': 79,
#   'age': 57,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 211.0,
#   'sysBP': 122.0,
#   'diaBP': 66.5,
#   'BMI': 20.19,
#   'heartRate': 62.0,
#   'glucose': 57.0,
#   'TenYearCHD': 0},
#  {'id': 80,
#   'age': 40,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 161.0,
#   'sysBP': 122.0,
#   'diaBP': 85.0,
#   'BMI': 30.8,
#   'heartRate': 75.0,
#   'glucose': 85.0,
#   'TenYearCHD': 1},
#  {'id': 81,
#   'age': 41,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 40.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 254.0,
#   'sysBP': 141.0,
#   'diaBP': 100.0,
#   'BMI': 27.68,
#   'heartRate': 110.0,
#   'glucose': nan,
#   'TenYearCHD': 1},
#  {'id': 82,
#   'age': 48,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 274.0,
#   'sysBP': 134.0,
#   'diaBP': 84.0,
#   'BMI': 31.78,
#   'heartRate': 85.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 83,
#   'age': 51,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 226.0,
#   'sysBP': 105.0,
#   'diaBP': 71.0,
#   'BMI': 27.73,
#   'heartRate': 68.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 84,
#   'age': 41,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 237.0,
#   'sysBP': 125.0,
#   'diaBP': 83.0,
#   'BMI': 24.56,
#   'heartRate': 73.0,
#   'glucose': 61.0,
#   'TenYearCHD': 0},
#  {'id': 85,
#   'age': 46,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 214.0,
#   'sysBP': 110.0,
#   'diaBP': 73.0,
#   'BMI': 18.1,
#   'heartRate': 60.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 86,
#   'age': 52,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 1,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 202.0,
#   'sysBP': 136.0,
#   'diaBP': 94.0,
#   'BMI': 29.93,
#   'heartRate': 83.0,
#   'glucose': 67.0,
#   'TenYearCHD': 1},
#  {'id': 87,
#   'age': 64,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 113.5,
#   'diaBP': 70.0,
#   'BMI': 21.03,
#   'heartRate': 80.0,
#   'glucose': 58.0,
#   'TenYearCHD': 1},
#  {'id': 88,
#   'age': 41,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 180.0,
#   'sysBP': 127.0,
#   'diaBP': 86.0,
#   'BMI': 20.72,
#   'heartRate': 73.0,
#   'glucose': 63.0,
#   'TenYearCHD': 0},
#  {'id': 89,
#   'age': 61,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 243.0,
#   'sysBP': 142.0,
#   'diaBP': 89.0,
#   'BMI': 27.3,
#   'heartRate': 65.0,
#   'glucose': 67.0,
#   'TenYearCHD': 1},
#  {'id': 90,
#   'age': 51,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 195.0,
#   'sysBP': 122.0,
#   'diaBP': 72.0,
#   'BMI': 21.51,
#   'heartRate': 82.0,
#   'glucose': 64.0,
#   'TenYearCHD': 1},
#  {'id': 91,
#   'age': 51,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 275.0,
#   'sysBP': 150.0,
#   'diaBP': 99.0,
#   'BMI': 23.17,
#   'heartRate': 75.0,
#   'glucose': 65.0,
#   'TenYearCHD': 0},
#  {'id': 92,
#   'age': 36,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 165.0,
#   'sysBP': 115.0,
#   'diaBP': 71.0,
#   'BMI': 21.27,
#   'heartRate': 64.0,
#   'glucose': 86.0,
#   'TenYearCHD': 0},
#  {'id': 93,
#   'age': 40,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 248.0,
#   'sysBP': 136.5,
#   'diaBP': 78.0,
#   'BMI': 24.6,
#   'heartRate': 90.0,
#   'glucose': 99.0,
#   'TenYearCHD': 0},
#  {'id': 94,
#   'age': 52,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 302.0,
#   'sysBP': 110.0,
#   'diaBP': 67.5,
#   'BMI': 23.51,
#   'heartRate': 63.0,
#   'glucose': 87.0,
#   'TenYearCHD': 0},
#  {'id': 95,
#   'age': 40,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 240.0,
#   'sysBP': 108.0,
#   'diaBP': 72.0,
#   'BMI': 17.64,
#   'heartRate': 78.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 96,
#   'age': 49,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 265.0,
#   'sysBP': 150.0,
#   'diaBP': 77.5,
#   'BMI': 21.83,
#   'heartRate': 96.0,
#   'glucose': 107.0,
#   'TenYearCHD': 0},
#  {'id': 97,
#   'age': 42,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 235.0,
#   'sysBP': 103.0,
#   'diaBP': 70.0,
#   'BMI': 21.48,
#   'heartRate': 67.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 98,
#   'age': 41,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 206.0,
#   'sysBP': 124.0,
#   'diaBP': 90.0,
#   'BMI': 30.69,
#   'heartRate': 75.0,
#   'glucose': 83.0,
#   'TenYearCHD': 0},
#  {'id': 99,
#   'age': 58,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 251.0,
#   'sysBP': 135.0,
#   'diaBP': 85.5,
#   'BMI': 21.24,
#   'heartRate': 88.0,
#   'glucose': 103.0,
#   'TenYearCHD': 0},
#  {'id': 100,
#   'age': 47,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 205.0,
#   'sysBP': 133.0,
#   'diaBP': 93.0,
#   'BMI': 27.82,
#   'heartRate': 68.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 101,
#   'age': 42,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 209.0,
#   'sysBP': 130.0,
#   'diaBP': 86.0,
#   'BMI': 24.01,
#   'heartRate': 60.0,
#   'glucose': 55.0,
#   'TenYearCHD': 0},
#  {'id': 102,
#   'age': 68,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': nan,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 257.0,
#   'sysBP': 144.0,
#   'diaBP': 95.0,
#   'BMI': 29.25,
#   'heartRate': 80.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 103,
#   'age': 48,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 258.0,
#   'sysBP': 150.0,
#   'diaBP': 105.0,
#   'BMI': 25.94,
#   'heartRate': 83.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 104,
#   'age': 57,
#   'education': nan,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 1.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 190.0,
#   'sysBP': 155.0,
#   'diaBP': 85.0,
#   'BMI': 26.08,
#   'heartRate': 55.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 105,
#   'age': 60,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 222.0,
#   'sysBP': 118.0,
#   'diaBP': 73.0,
#   'BMI': 24.48,
#   'heartRate': 75.0,
#   'glucose': 90.0,
#   'TenYearCHD': 0},
#  {'id': 106,
#   'age': 46,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 247.0,
#   'sysBP': 125.0,
#   'diaBP': 80.0,
#   'BMI': 21.51,
#   'heartRate': 60.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 107,
#   'age': 45,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 1,
#   'totChol': 189.0,
#   'sysBP': 132.0,
#   'diaBP': 78.0,
#   'BMI': 28.4,
#   'heartRate': 75.0,
#   'glucose': 177.0,
#   'TenYearCHD': 0},
#  {'id': 108,
#   'age': 49,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 288.0,
#   'sysBP': 128.0,
#   'diaBP': 89.0,
#   'BMI': 35.96,
#   'heartRate': 73.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 109,
#   'age': 42,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 173.0,
#   'sysBP': 100.0,
#   'diaBP': 63.0,
#   'BMI': 23.25,
#   'heartRate': 65.0,
#   'glucose': 99.0,
#   'TenYearCHD': 0},
#  {'id': 110,
#   'age': 42,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 9.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 281.0,
#   'sysBP': 115.5,
#   'diaBP': 79.0,
#   'BMI': 22.9,
#   'heartRate': 80.0,
#   'glucose': 71.0,
#   'TenYearCHD': 0},
#  {'id': 111,
#   'age': 45,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 250.0,
#   'sysBP': 130.0,
#   'diaBP': 80.0,
#   'BMI': 20.24,
#   'heartRate': 90.0,
#   'glucose': 86.0,
#   'TenYearCHD': 0},
#  {'id': 112,
#   'age': 57,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 382.0,
#   'sysBP': 133.0,
#   'diaBP': 77.0,
#   'BMI': 24.27,
#   'heartRate': 75.0,
#   'glucose': 81.0,
#   'TenYearCHD': 0},
#  {'id': 113,
#   'age': 41,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 181.0,
#   'sysBP': 125.0,
#   'diaBP': 79.0,
#   'BMI': 19.09,
#   'heartRate': 60.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 114,
#   'age': 40,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 200.0,
#   'sysBP': 116.0,
#   'diaBP': 69.0,
#   'BMI': 23.9,
#   'heartRate': 75.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 115,
#   'age': 52,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 244.0,
#   'sysBP': 127.5,
#   'diaBP': 72.5,
#   'BMI': 24.29,
#   'heartRate': 67.0,
#   'glucose': 118.0,
#   'TenYearCHD': 0},
#  {'id': 116,
#   'age': 39,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 213.0,
#   'sysBP': 125.0,
#   'diaBP': 87.0,
#   'BMI': 16.73,
#   'heartRate': 110.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 117,
#   'age': 45,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 122.5,
#   'diaBP': 82.5,
#   'BMI': 27.55,
#   'heartRate': 74.0,
#   'glucose': 59.0,
#   'TenYearCHD': 1},
#  {'id': 118,
#   'age': 48,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 17.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 218.0,
#   'sysBP': 113.0,
#   'diaBP': 79.0,
#   'BMI': 27.33,
#   'heartRate': 62.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 119,
#   'age': 64,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 213.0,
#   'sysBP': 133.0,
#   'diaBP': 77.5,
#   'BMI': 35.62,
#   'heartRate': 77.0,
#   'glucose': 74.0,
#   'TenYearCHD': 0},
#  {'id': 120,
#   'age': 65,
#   'education': nan,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 221.0,
#   'sysBP': 155.0,
#   'diaBP': 92.0,
#   'BMI': 31.34,
#   'heartRate': 58.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 121,
#   'age': 64,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 273.0,
#   'sysBP': 123.0,
#   'diaBP': 73.5,
#   'BMI': 22.3,
#   'heartRate': 75.0,
#   'glucose': 84.0,
#   'TenYearCHD': 1},
#  {'id': 122,
#   'age': 61,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 270.0,
#   'sysBP': 174.5,
#   'diaBP': 101.5,
#   'BMI': 29.87,
#   'heartRate': 80.0,
#   'glucose': 76.0,
#   'TenYearCHD': 0},
#  {'id': 123,
#   'age': 36,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 188.0,
#   'sysBP': 112.0,
#   'diaBP': 78.0,
#   'BMI': 22.54,
#   'heartRate': 63.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 124,
#   'age': 45,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 195.0,
#   'sysBP': 129.5,
#   'diaBP': 83.0,
#   'BMI': 25.74,
#   'heartRate': 77.0,
#   'glucose': 74.0,
#   'TenYearCHD': 0},
#  {'id': 125,
#   'age': 60,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 266.0,
#   'sysBP': 135.0,
#   'diaBP': 87.0,
#   'BMI': 26.72,
#   'heartRate': 75.0,
#   'glucose': 82.0,
#   'TenYearCHD': 0},
#  {'id': 126,
#   'age': 45,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 25.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 165.0,
#   'diaBP': 86.0,
#   'BMI': 23.86,
#   'heartRate': 78.0,
#   'glucose': 68.0,
#   'TenYearCHD': 0},
#  {'id': 127,
#   'age': 57,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 221.0,
#   'sysBP': 117.0,
#   'diaBP': 72.0,
#   'BMI': 25.51,
#   'heartRate': 75.0,
#   'glucose': 83.0,
#   'TenYearCHD': 1},
#  {'id': 128,
#   'age': 67,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': nan,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 261.0,
#   'sysBP': 117.0,
#   'diaBP': 63.0,
#   'BMI': 22.55,
#   'heartRate': 75.0,
#   'glucose': 83.0,
#   'TenYearCHD': 0},
#  {'id': 129,
#   'age': 62,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 214.0,
#   'sysBP': 110.0,
#   'diaBP': 62.5,
#   'BMI': 23.8,
#   'heartRate': 77.0,
#   'glucose': 95.0,
#   'TenYearCHD': 1},
#  {'id': 130,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 1,
#   'totChol': 229.0,
#   'sysBP': 109.0,
#   'diaBP': 75.0,
#   'BMI': 38.42,
#   'heartRate': 110.0,
#   'glucose': 120.0,
#   'TenYearCHD': 0},
#  {'id': 131,
#   'age': 47,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 200.0,
#   'sysBP': 126.0,
#   'diaBP': 86.0,
#   'BMI': 26.84,
#   'heartRate': 80.0,
#   'glucose': 96.0,
#   'TenYearCHD': 0},
#  {'id': 132,
#   'age': 48,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 268.0,
#   'sysBP': 117.5,
#   'diaBP': 80.0,
#   'BMI': 36.11,
#   'heartRate': 72.0,
#   'glucose': 67.0,
#   'TenYearCHD': 0},
#  {'id': 133,
#   'age': 61,
#   'education': nan,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 5.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 175.0,
#   'sysBP': 134.0,
#   'diaBP': 82.5,
#   'BMI': 18.59,
#   'heartRate': 72.0,
#   'glucose': 75.0,
#   'TenYearCHD': 1},
#  {'id': 134,
#   'age': 64,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 1,
#   'totChol': 262.0,
#   'sysBP': 147.0,
#   'diaBP': 90.0,
#   'BMI': 26.51,
#   'heartRate': 85.0,
#   'glucose': 173.0,
#   'TenYearCHD': 0},
#  {'id': 135,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 235.0,
#   'sysBP': 125.0,
#   'diaBP': 79.0,
#   'BMI': 24.38,
#   'heartRate': 96.0,
#   'glucose': 83.0,
#   'TenYearCHD': 0},
#  {'id': 136,
#   'age': 38,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 174.0,
#   'sysBP': 101.0,
#   'diaBP': 68.0,
#   'BMI': 27.47,
#   'heartRate': 85.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 137,
#   'age': 39,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 43.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 291.0,
#   'sysBP': 177.5,
#   'diaBP': 100.0,
#   'BMI': 25.74,
#   'heartRate': 67.0,
#   'glucose': 91.0,
#   'TenYearCHD': 0},
#  {'id': 138,
#   'age': 53,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 238.0,
#   'sysBP': 172.5,
#   'diaBP': 91.0,
#   'BMI': 24.16,
#   'heartRate': 112.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 139,
#   'age': 50,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 312.0,
#   'sysBP': 125.0,
#   'diaBP': 85.0,
#   'BMI': 27.07,
#   'heartRate': 88.0,
#   'glucose': 94.0,
#   'TenYearCHD': 0},
#  {'id': 140,
#   'age': 45,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 5.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 170.0,
#   'sysBP': 109.5,
#   'diaBP': 69.0,
#   'BMI': 17.38,
#   'heartRate': 88.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 141,
#   'age': 57,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 176.0,
#   'sysBP': 134.0,
#   'diaBP': 97.0,
#   'BMI': 38.14,
#   'heartRate': 68.0,
#   'glucose': 94.0,
#   'TenYearCHD': 0},
#  {'id': 142,
#   'age': 67,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 326.0,
#   'sysBP': 157.5,
#   'diaBP': 78.0,
#   'BMI': 24.63,
#   'heartRate': 85.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 143,
#   'age': 55,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 257.0,
#   'sysBP': 132.0,
#   'diaBP': 81.0,
#   'BMI': 27.49,
#   'heartRate': 60.0,
#   'glucose': 86.0,
#   'TenYearCHD': 0},
#  {'id': 144,
#   'age': 46,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 193.0,
#   'sysBP': 118.0,
#   'diaBP': 92.0,
#   'BMI': 21.14,
#   'heartRate': 75.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 145,
#   'age': 40,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 290.0,
#   'sysBP': 120.0,
#   'diaBP': 89.0,
#   'BMI': 27.99,
#   'heartRate': 80.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 146,
#   'age': 42,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 204.0,
#   'sysBP': 108.0,
#   'diaBP': 70.5,
#   'BMI': 27.71,
#   'heartRate': 75.0,
#   'glucose': 65.0,
#   'TenYearCHD': 0},
#  {'id': 147,
#   'age': 61,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 227.0,
#   'sysBP': 130.0,
#   'diaBP': 77.5,
#   'BMI': 26.18,
#   'heartRate': 63.0,
#   'glucose': 91.0,
#   'TenYearCHD': 0},
#  {'id': 148,
#   'age': 55,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 239.0,
#   'sysBP': 144.0,
#   'diaBP': 96.5,
#   'BMI': 28.82,
#   'heartRate': 70.0,
#   'glucose': 102.0,
#   'TenYearCHD': 0},
#  {'id': 149,
#   'age': 41,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 198.0,
#   'sysBP': 106.0,
#   'diaBP': 71.0,
#   'BMI': 21.51,
#   'heartRate': 85.0,
#   'glucose': 84.0,
#   'TenYearCHD': 0},
#  {'id': 150,
#   'age': 43,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 245.0,
#   'sysBP': 112.5,
#   'diaBP': 80.0,
#   'BMI': 23.43,
#   'heartRate': 90.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 151,
#   'age': 52,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 265.0,
#   'sysBP': 106.0,
#   'diaBP': 79.0,
#   'BMI': 26.48,
#   'heartRate': 80.0,
#   'glucose': 163.0,
#   'TenYearCHD': 1},
#  {'id': 152,
#   'age': 38,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 199.0,
#   'sysBP': 112.0,
#   'diaBP': 68.5,
#   'BMI': 23.88,
#   'heartRate': 85.0,
#   'glucose': 67.0,
#   'TenYearCHD': 0},
#  {'id': 153,
#   'age': 38,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
# ...
#   'age': 52,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 346.0,
#   'sysBP': 133.0,
#   'diaBP': 96.0,
#   'BMI': 25.95,
#   'heartRate': 65.0,
#   'glucose': 126.0,
#   'TenYearCHD': 1},
#  {'id': 950,
#   'age': 61,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 231.0,
#   'sysBP': 128.0,
#   'diaBP': 87.0,
#   'BMI': 26.3,
#   'heartRate': 82.0,
#   'glucose': 93.0,
#   'TenYearCHD': 0},
#  {'id': 951,
#   'age': 52,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 234.0,
#   'sysBP': 148.0,
#   'diaBP': 78.0,
#   'BMI': 34.17,
#   'heartRate': 70.0,
#   'glucose': 113.0,
#   'TenYearCHD': 0},
#  {'id': 952,
#   'age': 59,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 167.0,
#   'sysBP': 156.0,
#   'diaBP': 104.0,
#   'BMI': 15.96,
#   'heartRate': 72.0,
#   'glucose': 45.0,
#   'TenYearCHD': 1},
#  {'id': 953,
#   'age': 55,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 242.0,
#   'sysBP': 120.0,
#   'diaBP': 86.0,
#   'BMI': 26.77,
#   'heartRate': 55.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 954,
#   'age': 59,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 303.0,
#   'sysBP': 134.0,
#   'diaBP': 89.0,
#   'BMI': 24.07,
#   'heartRate': 78.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 955,
#   'age': 48,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 164.0,
#   'sysBP': 159.0,
#   'diaBP': 90.0,
#   'BMI': 26.73,
#   'heartRate': 80.0,
#   'glucose': 63.0,
#   'TenYearCHD': 0},
#  {'id': 956,
#   'age': 53,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 202.0,
#   'sysBP': 119.0,
#   'diaBP': 80.0,
#   'BMI': 23.98,
#   'heartRate': 64.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 957,
#   'age': 41,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 15.0,
#   'BPMeds': nan,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 198.0,
#   'sysBP': 114.5,
#   'diaBP': 80.0,
#   'BMI': 22.53,
#   'heartRate': 72.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 958,
#   'age': 54,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 1,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 321.0,
#   'sysBP': 150.0,
#   'diaBP': 93.0,
#   'BMI': 22.5,
#   'heartRate': 75.0,
#   'glucose': 131.0,
#   'TenYearCHD': 0},
#  {'id': 959,
#   'age': 65,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 1.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 201.0,
#   'sysBP': 166.0,
#   'diaBP': 93.0,
#   'BMI': 28.16,
#   'heartRate': 54.0,
#   'glucose': 91.0,
#   'TenYearCHD': 0},
#  {'id': 960,
#   'age': 59,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 206.0,
#   'sysBP': 115.0,
#   'diaBP': 70.0,
#   'BMI': 24.79,
#   'heartRate': 84.0,
#   'glucose': 76.0,
#   'TenYearCHD': 0},
#  {'id': 961,
#   'age': 50,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 270.0,
#   'sysBP': 142.5,
#   'diaBP': 85.0,
#   'BMI': 21.86,
#   'heartRate': 72.0,
#   'glucose': 75.0,
#   'TenYearCHD': 0},
#  {'id': 962,
#   'age': 50,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 250.0,
#   'sysBP': 109.0,
#   'diaBP': 70.0,
#   'BMI': 20.74,
#   'heartRate': 75.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 963,
#   'age': 46,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 25.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 165.0,
#   'sysBP': 99.5,
#   'diaBP': 66.0,
#   'BMI': 21.67,
#   'heartRate': 72.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 964,
#   'age': 38,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 167.0,
#   'sysBP': 105.0,
#   'diaBP': 70.0,
#   'BMI': 19.76,
#   'heartRate': 80.0,
#   'glucose': 80.0,
#   'TenYearCHD': 0},
#  {'id': 965,
#   'age': 54,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 262.0,
#   'sysBP': 113.5,
#   'diaBP': 80.0,
#   'BMI': 26.42,
#   'heartRate': 75.0,
#   'glucose': 67.0,
#   'TenYearCHD': 0},
#  {'id': 966,
#   'age': 42,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 233.0,
#   'sysBP': 132.0,
#   'diaBP': 82.0,
#   'BMI': 26.81,
#   'heartRate': 69.0,
#   'glucose': 71.0,
#   'TenYearCHD': 0},
#  {'id': 967,
#   'age': 38,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 227.0,
#   'sysBP': 117.5,
#   'diaBP': 77.5,
#   'BMI': 30.24,
#   'heartRate': 85.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 968,
#   'age': 39,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 173.0,
#   'sysBP': 109.0,
#   'diaBP': 82.0,
#   'BMI': 27.27,
#   'heartRate': 85.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 969,
#   'age': 36,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 30.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 155.0,
#   'sysBP': 126.0,
#   'diaBP': 72.0,
#   'BMI': 25.14,
#   'heartRate': 50.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 970,
#   'age': 60,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 1.0,
#   'BPMeds': 1.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 232.0,
#   'sysBP': 173.0,
#   'diaBP': 106.0,
#   'BMI': 28.63,
#   'heartRate': 85.0,
#   'glucose': 64.0,
#   'TenYearCHD': 0},
#  {'id': 971,
#   'age': 63,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 222.0,
#   'sysBP': 159.0,
#   'diaBP': 90.0,
#   'BMI': 21.9,
#   'heartRate': 80.0,
#   'glucose': 95.0,
#   'TenYearCHD': 1},
#  {'id': 972,
#   'age': 47,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 40.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 221.0,
#   'sysBP': 144.0,
#   'diaBP': 91.0,
#   'BMI': 35.78,
#   'heartRate': 85.0,
#   'glucose': 66.0,
#   'TenYearCHD': 0},
#  {'id': 973,
#   'age': 44,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 270.0,
#   'sysBP': 131.5,
#   'diaBP': 76.0,
#   'BMI': 22.19,
#   'heartRate': 68.0,
#   'glucose': 113.0,
#   'TenYearCHD': 0},
#  {'id': 974,
#   'age': 42,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 236.0,
#   'sysBP': 124.0,
#   'diaBP': 80.0,
#   'BMI': 21.5,
#   'heartRate': 65.0,
#   'glucose': 60.0,
#   'TenYearCHD': 0},
#  {'id': 975,
#   'age': 41,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 5.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 192.0,
#   'sysBP': 123.0,
#   'diaBP': 72.0,
#   'BMI': 19.16,
#   'heartRate': 62.0,
#   'glucose': 90.0,
#   'TenYearCHD': 1},
#  {'id': 976,
#   'age': 46,
#   'education': 3.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 300.0,
#   'sysBP': 146.0,
#   'diaBP': 98.5,
#   'BMI': 30.41,
#   'heartRate': 60.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  {'id': 977,
#   'age': 64,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 210.0,
#   'sysBP': 120.0,
#   'diaBP': 68.0,
#   'BMI': 24.77,
#   'heartRate': 80.0,
#   'glucose': 77.0,
#   'TenYearCHD': 1},
#  {'id': 978,
#   'age': 54,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 5.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 390.0,
#   'sysBP': 150.0,
#   'diaBP': 94.0,
#   'BMI': 27.34,
#   'heartRate': 75.0,
#   'glucose': 71.0,
#   'TenYearCHD': 0},
#  {'id': 979,
#   'age': 56,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 10.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 225.0,
#   'sysBP': 120.0,
#   'diaBP': 70.0,
#   'BMI': 18.46,
#   'heartRate': 57.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 980,
#   'age': 50,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 271.0,
#   'sysBP': 112.5,
#   'diaBP': 60.0,
#   'BMI': 23.29,
#   'heartRate': 60.0,
#   'glucose': 61.0,
#   'TenYearCHD': 0},
#  {'id': 981,
#   'age': 47,
#   'education': 4.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 294.0,
#   'sysBP': 102.0,
#   'diaBP': 68.0,
#   'BMI': 24.18,
#   'heartRate': 62.0,
#   'glucose': 66.0,
#   'TenYearCHD': 1},
#  {'id': 982,
#   'age': 40,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 332.0,
#   'sysBP': 114.0,
#   'diaBP': 76.0,
#   'BMI': 26.51,
#   'heartRate': 70.0,
#   'glucose': 90.0,
#   'TenYearCHD': 0},
#  {'id': 983,
#   'age': 45,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 156.0,
#   'sysBP': 119.0,
#   'diaBP': 83.0,
#   'BMI': 22.02,
#   'heartRate': 68.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 984,
#   'age': 57,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 262.0,
#   'sysBP': 131.5,
#   'diaBP': 92.0,
#   'BMI': 28.3,
#   'heartRate': 70.0,
#   'glucose': 78.0,
#   'TenYearCHD': 0},
#  {'id': 985,
#   'age': 55,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 222.0,
#   'sysBP': 103.0,
#   'diaBP': 61.0,
#   'BMI': 23.18,
#   'heartRate': 68.0,
#   'glucose': 75.0,
#   'TenYearCHD': 1},
#  {'id': 986,
#   'age': 43,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 240.0,
#   'sysBP': 141.5,
#   'diaBP': 93.0,
#   'BMI': 38.43,
#   'heartRate': 72.0,
#   'glucose': 77.0,
#   'TenYearCHD': 0},
#  {'id': 987,
#   'age': 56,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 207.0,
#   'sysBP': 120.0,
#   'diaBP': 60.0,
#   'BMI': 22.89,
#   'heartRate': 75.0,
#   'glucose': 71.0,
#   'TenYearCHD': 0},
#  {'id': 988,
#   'age': 59,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 43.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 162.0,
#   'sysBP': 117.0,
#   'diaBP': 73.0,
#   'BMI': 25.01,
#   'heartRate': 96.0,
#   'glucose': 87.0,
#   'TenYearCHD': 0},
#  {'id': 989,
#   'age': 42,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 220.0,
#   'sysBP': 129.0,
#   'diaBP': 81.0,
#   'BMI': 19.74,
#   'heartRate': 80.0,
#   'glucose': 61.0,
#   'TenYearCHD': 0},
#  {'id': 990,
#   'age': 54,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 239.0,
#   'sysBP': 142.5,
#   'diaBP': 83.5,
#   'BMI': 30.47,
#   'heartRate': 83.0,
#   'glucose': 84.0,
#   'TenYearCHD': 0},
#  {'id': 991,
#   'age': 44,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 319.0,
#   'sysBP': 158.0,
#   'diaBP': 90.0,
#   'BMI': 29.15,
#   'heartRate': 89.0,
#   'glucose': 100.0,
#   'TenYearCHD': 1},
#  {'id': 992,
#   'age': 54,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 227.0,
#   'sysBP': 168.0,
#   'diaBP': 94.0,
#   'BMI': 22.7,
#   'heartRate': 75.0,
#   'glucose': 70.0,
#   'TenYearCHD': 0},
#  {'id': 993,
#   'age': 43,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 1.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 210.0,
#   'sysBP': 181.0,
#   'diaBP': 97.5,
#   'BMI': 21.83,
#   'heartRate': 75.0,
#   'glucose': 55.0,
#   'TenYearCHD': 0},
#  {'id': 994,
#   'age': 46,
#   'education': 4.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 5.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 240.0,
#   'sysBP': 125.0,
#   'diaBP': 74.0,
#   'BMI': 22.89,
#   'heartRate': 87.0,
#   'glucose': 76.0,
#   'TenYearCHD': 0},
#  {'id': 995,
#   'age': 56,
#   'education': 1.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 3.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 268.0,
#   'sysBP': 170.0,
#   'diaBP': 102.0,
#   'BMI': 22.89,
#   'heartRate': 57.0,
#   'glucose': nan,
#   'TenYearCHD': 0},
#  {'id': 996,
#   'age': 39,
#   'education': 3.0,
#   'sex': 'F',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 1,
#   'totChol': 209.0,
#   'sysBP': 104.0,
#   'diaBP': 72.0,
#   'BMI': 23.96,
#   'heartRate': 90.0,
#   'glucose': 103.0,
#   'TenYearCHD': 0},
#  {'id': 997,
#   'age': 55,
#   'education': 2.0,
#   'sex': 'F',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 250.0,
#   'sysBP': 138.0,
#   'diaBP': 87.0,
#   'BMI': 25.33,
#   'heartRate': 95.0,
#   'glucose': nan,
#   'TenYearCHD': 1},
#  {'id': 998,
#   'age': 61,
#   'education': 1.0,
#   'sex': 'M',
#   'is_smoking': 'YES',
#   'cigsPerDay': 20.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 1,
#   'diabetes': 0,
#   'totChol': 360.0,
#   'sysBP': 157.0,
#   'diaBP': 99.0,
#   'BMI': 28.74,
#   'heartRate': 95.0,
#   'glucose': 73.0,
#   'TenYearCHD': 0},
#  {'id': 999,
#   'age': 39,
#   'education': 2.0,
#   'sex': 'M',
#   'is_smoking': 'NO',
#   'cigsPerDay': 0.0,
#   'BPMeds': 0.0,
#   'prevalentStroke': 0,
#   'prevalentHyp': 0,
#   'diabetes': 0,
#   'totChol': 258.0,
#   'sysBP': 105.0,
#   'diaBP': 69.0,
#   'BMI': 24.1,
#   'heartRate': 52.0,
#   'glucose': 79.0,
#   'TenYearCHD': 0},
#  ...]

# %%
DB_NAME='Cardeo_vascular_risk_DB'
COLLECTION_NAME="Cardeo_data"
CONNECTION_URL="mongodb+srv://kumarlova078:kumarlova078@cluster0.sqvyb.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# Create a MongoDB client
client = pymongo.MongoClient(CONNECTION_URL)

# Access the database
db = client[DB_NAME]

# Access the collection
collection = db[COLLECTION_NAME]
## record
rec=collection.insert_many(data)


print("Connected to MongoDB")
# Out:
# Connected to MongoDB

# %%
records=collection.find()
records

# %%
for i,j in enumerate(records):
    print(f"{i} ,{j}")
# Out:
# 0 ,{'_id': ObjectId('67864ff437f5a75d634d2260'), 'id': 0, 'age': 64, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 221.0, 'sysBP': 148.0, 'diaBP': 85.0, 'BMI': nan, 'heartRate': 90.0, 'glucose': 80.0, 'TenYearCHD': 1}
# 1 ,{'_id': ObjectId('67864ff437f5a75d634d2261'), 'id': 1, 'age': 36, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 212.0, 'sysBP': 168.0, 'diaBP': 98.0, 'BMI': 29.77, 'heartRate': 72.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 2 ,{'_id': ObjectId('67864ff437f5a75d634d2262'), 'id': 2, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 250.0, 'sysBP': 116.0, 'diaBP': 71.0, 'BMI': 20.35, 'heartRate': 88.0, 'glucose': 94.0, 'TenYearCHD': 0}
# 3 ,{'_id': ObjectId('67864ff437f5a75d634d2263'), 'id': 3, 'age': 50, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 233.0, 'sysBP': 158.0, 'diaBP': 88.0, 'BMI': 28.26, 'heartRate': 68.0, 'glucose': 94.0, 'TenYearCHD': 1}
# 4 ,{'_id': ObjectId('67864ff437f5a75d634d2264'), 'id': 4, 'age': 64, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 241.0, 'sysBP': 136.5, 'diaBP': 85.0, 'BMI': 26.42, 'heartRate': 70.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 5 ,{'_id': ObjectId('67864ff437f5a75d634d2265'), 'id': 5, 'age': 61, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 272.0, 'sysBP': 182.0, 'diaBP': 121.0, 'BMI': 32.8, 'heartRate': 85.0, 'glucose': 65.0, 'TenYearCHD': 1}
# 6 ,{'_id': ObjectId('67864ff437f5a75d634d2266'), 'id': 6, 'age': 61, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 238.0, 'sysBP': 232.0, 'diaBP': 136.0, 'BMI': 24.83, 'heartRate': 75.0, 'glucose': 79.0, 'TenYearCHD': 0}
# 7 ,{'_id': ObjectId('67864ff437f5a75d634d2267'), 'id': 7, 'age': 36, 'education': 4.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 35.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 295.0, 'sysBP': 102.0, 'diaBP': 68.0, 'BMI': 28.15, 'heartRate': 60.0, 'glucose': 63.0, 'TenYearCHD': 0}
# 8 ,{'_id': ObjectId('67864ff437f5a75d634d2268'), 'id': 8, 'age': 41, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': nan, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 220.0, 'sysBP': 126.0, 'diaBP': 78.0, 'BMI': 20.7, 'heartRate': 86.0, 'glucose': 79.0, 'TenYearCHD': 0}
# 9 ,{'_id': ObjectId('67864ff437f5a75d634d2269'), 'id': 9, 'age': 55, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 326.0, 'sysBP': 144.0, 'diaBP': 81.0, 'BMI': 25.71, 'heartRate': 85.0, 'glucose': nan, 'TenYearCHD': 0}
# 10 ,{'_id': ObjectId('67864ff437f5a75d634d226a'), 'id': 10, 'age': 61, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': nan, 'sysBP': 185.0, 'diaBP': 121.0, 'BMI': 35.22, 'heartRate': 80.0, 'glucose': nan, 'TenYearCHD': 0}
# 11 ,{'_id': ObjectId('67864ff437f5a75d634d226b'), 'id': 11, 'age': 53, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 210.0, 'sysBP': 138.0, 'diaBP': 86.5, 'BMI': 22.49, 'heartRate': 88.0, 'glucose': 87.0, 'TenYearCHD': 0}
# 12 ,{'_id': ObjectId('67864ff437f5a75d634d226c'), 'id': 12, 'age': 43, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 213.0, 'sysBP': 96.0, 'diaBP': 62.0, 'BMI': 19.38, 'heartRate': 74.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 13 ,{'_id': ObjectId('67864ff437f5a75d634d226d'), 'id': 13, 'age': 44, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 40.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 227.0, 'sysBP': 146.5, 'diaBP': 97.0, 'BMI': 26.92, 'heartRate': 80.0, 'glucose': 67.0, 'TenYearCHD': 0}
# 14 ,{'_id': ObjectId('67864ff437f5a75d634d226e'), 'id': 14, 'age': 58, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 188.0, 'sysBP': 160.0, 'diaBP': 120.0, 'BMI': 35.58, 'heartRate': 88.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 15 ,{'_id': ObjectId('67864ff437f5a75d634d226f'), 'id': 15, 'age': 51, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 15.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 212.0, 'sysBP': 146.0, 'diaBP': 89.0, 'BMI': 24.49, 'heartRate': 100.0, 'glucose': 132.0, 'TenYearCHD': 1}
# 16 ,{'_id': ObjectId('67864ff437f5a75d634d2270'), 'id': 16, 'age': 50, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 240.0, 'sysBP': 163.0, 'diaBP': 105.0, 'BMI': 31.37, 'heartRate': 89.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 17 ,{'_id': ObjectId('67864ff437f5a75d634d2271'), 'id': 17, 'age': 44, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 257.0, 'sysBP': 129.0, 'diaBP': 93.0, 'BMI': 27.56, 'heartRate': 75.0, 'glucose': 76.0, 'TenYearCHD': 0}
# 18 ,{'_id': ObjectId('67864ff437f5a75d634d2272'), 'id': 18, 'age': 56, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 267.0, 'sysBP': 122.5, 'diaBP': 85.0, 'BMI': 24.22, 'heartRate': 92.0, 'glucose': 100.0, 'TenYearCHD': 0}
# 19 ,{'_id': ObjectId('67864ff437f5a75d634d2273'), 'id': 19, 'age': 42, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 232.0, 'sysBP': 130.0, 'diaBP': 91.0, 'BMI': 25.77, 'heartRate': 72.0, 'glucose': 70.0, 'TenYearCHD': 0}
# 20 ,{'_id': ObjectId('67864ff437f5a75d634d2274'), 'id': 20, 'age': 42, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 199.0, 'sysBP': 141.0, 'diaBP': 92.0, 'BMI': 43.69, 'heartRate': 80.0, 'glucose': 60.0, 'TenYearCHD': 1}
# 21 ,{'_id': ObjectId('67864ff437f5a75d634d2275'), 'id': 21, 'age': 38, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 175.0, 'sysBP': 142.0, 'diaBP': 86.0, 'BMI': 22.01, 'heartRate': 82.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 22 ,{'_id': ObjectId('67864ff437f5a75d634d2276'), 'id': 22, 'age': 38, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 164.0, 'sysBP': 113.0, 'diaBP': 68.0, 'BMI': 25.75, 'heartRate': 70.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 23 ,{'_id': ObjectId('67864ff437f5a75d634d2277'), 'id': 23, 'age': 63, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 226.0, 'sysBP': 172.5, 'diaBP': 98.0, 'BMI': 26.47, 'heartRate': 87.0, 'glucose': 81.0, 'TenYearCHD': 0}
# 24 ,{'_id': ObjectId('67864ff437f5a75d634d2278'), 'id': 24, 'age': 35, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 248.0, 'sysBP': 107.0, 'diaBP': 73.0, 'BMI': 20.64, 'heartRate': 90.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 25 ,{'_id': ObjectId('67864ff437f5a75d634d2279'), 'id': 25, 'age': 44, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 220.0, 'sysBP': 105.0, 'diaBP': 70.0, 'BMI': 21.01, 'heartRate': 58.0, 'glucose': 68.0, 'TenYearCHD': 0}
# 26 ,{'_id': ObjectId('67864ff437f5a75d634d227a'), 'id': 26, 'age': 36, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 15.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 245.0, 'sysBP': 122.0, 'diaBP': 74.5, 'BMI': 24.27, 'heartRate': 79.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 27 ,{'_id': ObjectId('67864ff437f5a75d634d227b'), 'id': 27, 'age': 54, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 279.0, 'sysBP': 155.0, 'diaBP': 105.0, 'BMI': 26.47, 'heartRate': 78.0, 'glucose': 66.0, 'TenYearCHD': 0}
# 28 ,{'_id': ObjectId('67864ff437f5a75d634d227c'), 'id': 28, 'age': 41, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 245.0, 'sysBP': 134.0, 'diaBP': 98.0, 'BMI': 24.26, 'heartRate': 85.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 29 ,{'_id': ObjectId('67864ff437f5a75d634d227d'), 'id': 29, 'age': 63, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 1, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 273.0, 'sysBP': 152.0, 'diaBP': 70.0, 'BMI': 19.69, 'heartRate': 80.0, 'glucose': 79.0, 'TenYearCHD': 1}
# 30 ,{'_id': ObjectId('67864ff437f5a75d634d227e'), 'id': 30, 'age': 51, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 227.0, 'sysBP': 158.0, 'diaBP': 105.0, 'BMI': 27.22, 'heartRate': 60.0, 'glucose': 96.0, 'TenYearCHD': 1}
# 31 ,{'_id': ObjectId('67864ff437f5a75d634d227f'), 'id': 31, 'age': 55, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 252.0, 'sysBP': 129.0, 'diaBP': 84.0, 'BMI': 23.55, 'heartRate': 80.0, 'glucose': 72.0, 'TenYearCHD': 0}
# 32 ,{'_id': ObjectId('67864ff437f5a75d634d2280'), 'id': 32, 'age': 51, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 198.0, 'sysBP': 142.5, 'diaBP': 80.0, 'BMI': 23.86, 'heartRate': 76.0, 'glucose': 100.0, 'TenYearCHD': 0}
# 33 ,{'_id': ObjectId('67864ff437f5a75d634d2281'), 'id': 33, 'age': 38, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 266.0, 'sysBP': 149.0, 'diaBP': 91.0, 'BMI': 31.08, 'heartRate': 69.0, 'glucose': 61.0, 'TenYearCHD': 0}
# 34 ,{'_id': ObjectId('67864ff437f5a75d634d2282'), 'id': 34, 'age': 62, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 216.0, 'sysBP': 126.0, 'diaBP': 82.0, 'BMI': 21.18, 'heartRate': 69.0, 'glucose': 69.0, 'TenYearCHD': 0}
# 35 ,{'_id': ObjectId('67864ff437f5a75d634d2283'), 'id': 35, 'age': 47, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 237.0, 'sysBP': 130.0, 'diaBP': 78.0, 'BMI': 19.66, 'heartRate': 80.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 36 ,{'_id': ObjectId('67864ff437f5a75d634d2284'), 'id': 36, 'age': 46, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 193.0, 'sysBP': 106.5, 'diaBP': 70.5, 'BMI': 26.18, 'heartRate': 75.0, 'glucose': nan, 'TenYearCHD': 0}
# 37 ,{'_id': ObjectId('67864ff437f5a75d634d2285'), 'id': 37, 'age': 63, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 293.0, 'sysBP': 186.5, 'diaBP': 97.0, 'BMI': 30.47, 'heartRate': 60.0, 'glucose': 96.0, 'TenYearCHD': 0}
# 38 ,{'_id': ObjectId('67864ff437f5a75d634d2286'), 'id': 38, 'age': 41, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 9.0, 'BPMeds': 1.0, 'prevalentStroke': 1, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 180.0, 'sysBP': 114.0, 'diaBP': 70.0, 'BMI': 22.41, 'heartRate': 92.0, 'glucose': nan, 'TenYearCHD': 0}
# 39 ,{'_id': ObjectId('67864ff437f5a75d634d2287'), 'id': 39, 'age': 43, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 237.0, 'sysBP': 104.0, 'diaBP': 74.0, 'BMI': 23.02, 'heartRate': 60.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 40 ,{'_id': ObjectId('67864ff437f5a75d634d2288'), 'id': 40, 'age': 34, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 206.0, 'sysBP': 101.0, 'diaBP': 63.0, 'BMI': 21.5, 'heartRate': 75.0, 'glucose': 66.0, 'TenYearCHD': 0}
# 41 ,{'_id': ObjectId('67864ff437f5a75d634d2289'), 'id': 41, 'age': 51, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 199.0, 'sysBP': 113.0, 'diaBP': 68.0, 'BMI': 22.46, 'heartRate': 58.0, 'glucose': 68.0, 'TenYearCHD': 0}
# 42 ,{'_id': ObjectId('67864ff437f5a75d634d228a'), 'id': 42, 'age': 39, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 60.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 215.0, 'sysBP': 112.0, 'diaBP': 65.0, 'BMI': 23.6, 'heartRate': 59.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 43 ,{'_id': ObjectId('67864ff437f5a75d634d228b'), 'id': 43, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 208.0, 'sysBP': 122.0, 'diaBP': 76.0, 'BMI': 18.4, 'heartRate': 75.0, 'glucose': 70.0, 'TenYearCHD': 0}
# 44 ,{'_id': ObjectId('67864ff437f5a75d634d228c'), 'id': 44, 'age': 51, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 262.0, 'sysBP': 102.0, 'diaBP': 64.0, 'BMI': 28.06, 'heartRate': 80.0, 'glucose': 66.0, 'TenYearCHD': 0}
# 45 ,{'_id': ObjectId('67864ff437f5a75d634d228d'), 'id': 45, 'age': 64, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 270.0, 'sysBP': 142.0, 'diaBP': 68.0, 'BMI': 21.32, 'heartRate': 76.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 46 ,{'_id': ObjectId('67864ff437f5a75d634d228e'), 'id': 46, 'age': 55, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 293.0, 'sysBP': 165.0, 'diaBP': 106.0, 'BMI': 24.71, 'heartRate': 90.0, 'glucose': 79.0, 'TenYearCHD': 0}
# 47 ,{'_id': ObjectId('67864ff437f5a75d634d228f'), 'id': 47, 'age': 59, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 292.0, 'sysBP': 114.0, 'diaBP': 84.0, 'BMI': 27.39, 'heartRate': 68.0, 'glucose': 72.0, 'TenYearCHD': 0}
# 48 ,{'_id': ObjectId('67864ff437f5a75d634d2290'), 'id': 48, 'age': 55, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 346.0, 'sysBP': 131.0, 'diaBP': 81.0, 'BMI': 22.69, 'heartRate': 75.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 49 ,{'_id': ObjectId('67864ff437f5a75d634d2291'), 'id': 49, 'age': 46, 'education': nan, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 212.0, 'sysBP': 122.5, 'diaBP': 75.5, 'BMI': 23.51, 'heartRate': 67.0, 'glucose': 103.0, 'TenYearCHD': 0}
# 50 ,{'_id': ObjectId('67864ff437f5a75d634d2292'), 'id': 50, 'age': 62, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 202.0, 'sysBP': 111.0, 'diaBP': 79.5, 'BMI': 27.91, 'heartRate': 80.0, 'glucose': 100.0, 'TenYearCHD': 0}
# 51 ,{'_id': ObjectId('67864ff437f5a75d634d2293'), 'id': 51, 'age': 56, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 340.0, 'sysBP': 134.0, 'diaBP': 89.5, 'BMI': 21.91, 'heartRate': 50.0, 'glucose': 72.0, 'TenYearCHD': 1}
# 52 ,{'_id': ObjectId('67864ff437f5a75d634d2294'), 'id': 52, 'age': 45, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 262.0, 'sysBP': 133.0, 'diaBP': 83.0, 'BMI': 22.19, 'heartRate': 76.0, 'glucose': 92.0, 'TenYearCHD': 1}
# 53 ,{'_id': ObjectId('67864ff437f5a75d634d2295'), 'id': 53, 'age': 44, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 334.0, 'sysBP': 131.0, 'diaBP': 74.0, 'BMI': 28.82, 'heartRate': 80.0, 'glucose': 77.0, 'TenYearCHD': 1}
# 54 ,{'_id': ObjectId('67864ff437f5a75d634d2296'), 'id': 54, 'age': 63, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 1, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 213.0, 'sysBP': 163.0, 'diaBP': 94.0, 'BMI': nan, 'heartRate': 76.0, 'glucose': 69.0, 'TenYearCHD': 1}
# 55 ,{'_id': ObjectId('67864ff437f5a75d634d2297'), 'id': 55, 'age': 51, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 351.0, 'sysBP': 134.0, 'diaBP': 97.5, 'BMI': 21.66, 'heartRate': 100.0, 'glucose': nan, 'TenYearCHD': 0}
# 56 ,{'_id': ObjectId('67864ff437f5a75d634d2298'), 'id': 56, 'age': 49, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 9.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 235.0, 'sysBP': 109.0, 'diaBP': 70.0, 'BMI': 28.66, 'heartRate': 74.0, 'glucose': 73.0, 'TenYearCHD': 1}
# 57 ,{'_id': ObjectId('67864ff437f5a75d634d2299'), 'id': 57, 'age': 55, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 243.0, 'sysBP': 142.0, 'diaBP': 92.0, 'BMI': 30.24, 'heartRate': 70.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 58 ,{'_id': ObjectId('67864ff437f5a75d634d229a'), 'id': 58, 'age': 46, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 196.0, 'sysBP': 114.0, 'diaBP': 75.0, 'BMI': 21.01, 'heartRate': 60.0, 'glucose': 69.0, 'TenYearCHD': 0}
# 59 ,{'_id': ObjectId('67864ff437f5a75d634d229b'), 'id': 59, 'age': 60, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 275.0, 'sysBP': 141.0, 'diaBP': 84.0, 'BMI': 29.66, 'heartRate': 75.0, 'glucose': 105.0, 'TenYearCHD': 0}
# 60 ,{'_id': ObjectId('67864ff437f5a75d634d229c'), 'id': 60, 'age': 38, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 186.0, 'sysBP': 105.0, 'diaBP': 57.0, 'BMI': 21.1, 'heartRate': 85.0, 'glucose': 68.0, 'TenYearCHD': 0}
# 61 ,{'_id': ObjectId('67864ff437f5a75d634d229d'), 'id': 61, 'age': 40, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 190.0, 'sysBP': 121.5, 'diaBP': 74.5, 'BMI': 29.35, 'heartRate': 73.0, 'glucose': 93.0, 'TenYearCHD': 0}
# 62 ,{'_id': ObjectId('67864ff437f5a75d634d229e'), 'id': 62, 'age': 52, 'education': nan, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 268.0, 'sysBP': 109.0, 'diaBP': 70.0, 'BMI': 23.74, 'heartRate': 75.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 63 ,{'_id': ObjectId('67864ff437f5a75d634d229f'), 'id': 63, 'age': 48, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 234.0, 'sysBP': 144.0, 'diaBP': 90.0, 'BMI': 29.34, 'heartRate': 72.0, 'glucose': 70.0, 'TenYearCHD': 0}
# 64 ,{'_id': ObjectId('67864ff437f5a75d634d22a0'), 'id': 64, 'age': 62, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 264.0, 'sysBP': 129.0, 'diaBP': 85.0, 'BMI': 26.15, 'heartRate': 73.0, 'glucose': 63.0, 'TenYearCHD': 0}
# 65 ,{'_id': ObjectId('67864ff437f5a75d634d22a1'), 'id': 65, 'age': 37, 'education': 4.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 156.0, 'sysBP': 120.0, 'diaBP': 87.0, 'BMI': 21.8, 'heartRate': 66.0, 'glucose': 89.0, 'TenYearCHD': 0}
# 66 ,{'_id': ObjectId('67864ff437f5a75d634d22a2'), 'id': 66, 'age': 60, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 260.0, 'sysBP': 178.0, 'diaBP': 103.0, 'BMI': 24.62, 'heartRate': 72.0, 'glucose': 79.0, 'TenYearCHD': 0}
# 67 ,{'_id': ObjectId('67864ff437f5a75d634d22a3'), 'id': 67, 'age': 60, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 225.0, 'sysBP': 149.0, 'diaBP': 96.0, 'BMI': 27.73, 'heartRate': 80.0, 'glucose': 60.0, 'TenYearCHD': 0}
# 68 ,{'_id': ObjectId('67864ff437f5a75d634d22a4'), 'id': 68, 'age': 61, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 183.0, 'sysBP': 150.0, 'diaBP': 86.0, 'BMI': 25.05, 'heartRate': 66.0, 'glucose': 70.0, 'TenYearCHD': 1}
# 69 ,{'_id': ObjectId('67864ff437f5a75d634d22a5'), 'id': 69, 'age': 65, 'education': nan, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': nan, 'sysBP': 152.5, 'diaBP': 97.5, 'BMI': 28.35, 'heartRate': 65.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 70 ,{'_id': ObjectId('67864ff437f5a75d634d22a6'), 'id': 70, 'age': 50, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 210.0, 'sysBP': 121.5, 'diaBP': 78.0, 'BMI': 26.29, 'heartRate': 88.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 71 ,{'_id': ObjectId('67864ff437f5a75d634d22a7'), 'id': 71, 'age': 63, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 246.0, 'sysBP': 193.0, 'diaBP': 104.0, 'BMI': 23.08, 'heartRate': 80.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 72 ,{'_id': ObjectId('67864ff437f5a75d634d22a8'), 'id': 72, 'age': 42, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 237.0, 'sysBP': 105.0, 'diaBP': 75.0, 'BMI': 23.85, 'heartRate': 70.0, 'glucose': 87.0, 'TenYearCHD': 0}
# 73 ,{'_id': ObjectId('67864ff437f5a75d634d22a9'), 'id': 73, 'age': 58, 'education': 4.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 268.0, 'sysBP': 151.0, 'diaBP': 98.0, 'BMI': 20.34, 'heartRate': 72.0, 'glucose': 60.0, 'TenYearCHD': 0}
# 74 ,{'_id': ObjectId('67864ff437f5a75d634d22aa'), 'id': 74, 'age': 36, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 174.0, 'sysBP': 131.0, 'diaBP': 86.0, 'BMI': 26.23, 'heartRate': 75.0, 'glucose': 64.0, 'TenYearCHD': 0}
# 75 ,{'_id': ObjectId('67864ff437f5a75d634d22ab'), 'id': 75, 'age': 62, 'education': 4.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 288.0, 'sysBP': 118.5, 'diaBP': 71.0, 'BMI': 26.18, 'heartRate': 68.0, 'glucose': 87.0, 'TenYearCHD': 0}
# 76 ,{'_id': ObjectId('67864ff437f5a75d634d22ac'), 'id': 76, 'age': 37, 'education': 4.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 60.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 254.0, 'sysBP': 122.5, 'diaBP': 82.5, 'BMI': 23.87, 'heartRate': 88.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 77 ,{'_id': ObjectId('67864ff437f5a75d634d22ad'), 'id': 77, 'age': 63, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 1, 'totChol': 150.0, 'sysBP': 152.0, 'diaBP': 88.0, 'BMI': 36.54, 'heartRate': 72.0, 'glucose': 170.0, 'TenYearCHD': 0}
# 78 ,{'_id': ObjectId('67864ff437f5a75d634d22ae'), 'id': 78, 'age': 52, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 232.0, 'sysBP': 155.0, 'diaBP': 80.5, 'BMI': 29.6, 'heartRate': 72.0, 'glucose': 67.0, 'TenYearCHD': 0}
# 79 ,{'_id': ObjectId('67864ff437f5a75d634d22af'), 'id': 79, 'age': 57, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 211.0, 'sysBP': 122.0, 'diaBP': 66.5, 'BMI': 20.19, 'heartRate': 62.0, 'glucose': 57.0, 'TenYearCHD': 0}
# 80 ,{'_id': ObjectId('67864ff437f5a75d634d22b0'), 'id': 80, 'age': 40, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 161.0, 'sysBP': 122.0, 'diaBP': 85.0, 'BMI': 30.8, 'heartRate': 75.0, 'glucose': 85.0, 'TenYearCHD': 1}
# 81 ,{'_id': ObjectId('67864ff437f5a75d634d22b1'), 'id': 81, 'age': 41, 'education': 4.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 40.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 254.0, 'sysBP': 141.0, 'diaBP': 100.0, 'BMI': 27.68, 'heartRate': 110.0, 'glucose': nan, 'TenYearCHD': 1}
# 82 ,{'_id': ObjectId('67864ff437f5a75d634d22b2'), 'id': 82, 'age': 48, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 274.0, 'sysBP': 134.0, 'diaBP': 84.0, 'BMI': 31.78, 'heartRate': 85.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 83 ,{'_id': ObjectId('67864ff437f5a75d634d22b3'), 'id': 83, 'age': 51, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 226.0, 'sysBP': 105.0, 'diaBP': 71.0, 'BMI': 27.73, 'heartRate': 68.0, 'glucose': 79.0, 'TenYearCHD': 0}
# 84 ,{'_id': ObjectId('67864ff437f5a75d634d22b4'), 'id': 84, 'age': 41, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 237.0, 'sysBP': 125.0, 'diaBP': 83.0, 'BMI': 24.56, 'heartRate': 73.0, 'glucose': 61.0, 'TenYearCHD': 0}
# 85 ,{'_id': ObjectId('67864ff437f5a75d634d22b5'), 'id': 85, 'age': 46, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 214.0, 'sysBP': 110.0, 'diaBP': 73.0, 'BMI': 18.1, 'heartRate': 60.0, 'glucose': 60.0, 'TenYearCHD': 0}
# 86 ,{'_id': ObjectId('67864ff437f5a75d634d22b6'), 'id': 86, 'age': 52, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 1, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 202.0, 'sysBP': 136.0, 'diaBP': 94.0, 'BMI': 29.93, 'heartRate': 83.0, 'glucose': 67.0, 'TenYearCHD': 1}
# 87 ,{'_id': ObjectId('67864ff437f5a75d634d22b7'), 'id': 87, 'age': 64, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 232.0, 'sysBP': 113.5, 'diaBP': 70.0, 'BMI': 21.03, 'heartRate': 80.0, 'glucose': 58.0, 'TenYearCHD': 1}
# 88 ,{'_id': ObjectId('67864ff437f5a75d634d22b8'), 'id': 88, 'age': 41, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 180.0, 'sysBP': 127.0, 'diaBP': 86.0, 'BMI': 20.72, 'heartRate': 73.0, 'glucose': 63.0, 'TenYearCHD': 0}
# 89 ,{'_id': ObjectId('67864ff437f5a75d634d22b9'), 'id': 89, 'age': 61, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 243.0, 'sysBP': 142.0, 'diaBP': 89.0, 'BMI': 27.3, 'heartRate': 65.0, 'glucose': 67.0, 'TenYearCHD': 1}
# 90 ,{'_id': ObjectId('67864ff437f5a75d634d22ba'), 'id': 90, 'age': 51, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 195.0, 'sysBP': 122.0, 'diaBP': 72.0, 'BMI': 21.51, 'heartRate': 82.0, 'glucose': 64.0, 'TenYearCHD': 1}
# 91 ,{'_id': ObjectId('67864ff437f5a75d634d22bb'), 'id': 91, 'age': 51, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 15.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 275.0, 'sysBP': 150.0, 'diaBP': 99.0, 'BMI': 23.17, 'heartRate': 75.0, 'glucose': 65.0, 'TenYearCHD': 0}
# 92 ,{'_id': ObjectId('67864ff437f5a75d634d22bc'), 'id': 92, 'age': 36, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 165.0, 'sysBP': 115.0, 'diaBP': 71.0, 'BMI': 21.27, 'heartRate': 64.0, 'glucose': 86.0, 'TenYearCHD': 0}
# 93 ,{'_id': ObjectId('67864ff437f5a75d634d22bd'), 'id': 93, 'age': 40, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 248.0, 'sysBP': 136.5, 'diaBP': 78.0, 'BMI': 24.6, 'heartRate': 90.0, 'glucose': 99.0, 'TenYearCHD': 0}
# 94 ,{'_id': ObjectId('67864ff437f5a75d634d22be'), 'id': 94, 'age': 52, 'education': 4.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 302.0, 'sysBP': 110.0, 'diaBP': 67.5, 'BMI': 23.51, 'heartRate': 63.0, 'glucose': 87.0, 'TenYearCHD': 0}
# 95 ,{'_id': ObjectId('67864ff437f5a75d634d22bf'), 'id': 95, 'age': 40, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 240.0, 'sysBP': 108.0, 'diaBP': 72.0, 'BMI': 17.64, 'heartRate': 78.0, 'glucose': nan, 'TenYearCHD': 0}
# 96 ,{'_id': ObjectId('67864ff437f5a75d634d22c0'), 'id': 96, 'age': 49, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 265.0, 'sysBP': 150.0, 'diaBP': 77.5, 'BMI': 21.83, 'heartRate': 96.0, 'glucose': 107.0, 'TenYearCHD': 0}
# 97 ,{'_id': ObjectId('67864ff437f5a75d634d22c1'), 'id': 97, 'age': 42, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 235.0, 'sysBP': 103.0, 'diaBP': 70.0, 'BMI': 21.48, 'heartRate': 67.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 98 ,{'_id': ObjectId('67864ff437f5a75d634d22c2'), 'id': 98, 'age': 41, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 206.0, 'sysBP': 124.0, 'diaBP': 90.0, 'BMI': 30.69, 'heartRate': 75.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 99 ,{'_id': ObjectId('67864ff437f5a75d634d22c3'), 'id': 99, 'age': 58, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 251.0, 'sysBP': 135.0, 'diaBP': 85.5, 'BMI': 21.24, 'heartRate': 88.0, 'glucose': 103.0, 'TenYearCHD': 0}
# 100 ,{'_id': ObjectId('67864ff437f5a75d634d22c4'), 'id': 100, 'age': 47, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 205.0, 'sysBP': 133.0, 'diaBP': 93.0, 'BMI': 27.82, 'heartRate': 68.0, 'glucose': 60.0, 'TenYearCHD': 0}
# 101 ,{'_id': ObjectId('67864ff437f5a75d634d22c5'), 'id': 101, 'age': 42, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 209.0, 'sysBP': 130.0, 'diaBP': 86.0, 'BMI': 24.01, 'heartRate': 60.0, 'glucose': 55.0, 'TenYearCHD': 0}
# 102 ,{'_id': ObjectId('67864ff437f5a75d634d22c6'), 'id': 102, 'age': 68, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': nan, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 257.0, 'sysBP': 144.0, 'diaBP': 95.0, 'BMI': 29.25, 'heartRate': 80.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 103 ,{'_id': ObjectId('67864ff437f5a75d634d22c7'), 'id': 103, 'age': 48, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 258.0, 'sysBP': 150.0, 'diaBP': 105.0, 'BMI': 25.94, 'heartRate': 83.0, 'glucose': 60.0, 'TenYearCHD': 0}
# 104 ,{'_id': ObjectId('67864ff437f5a75d634d22c8'), 'id': 104, 'age': 57, 'education': nan, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 1.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 190.0, 'sysBP': 155.0, 'diaBP': 85.0, 'BMI': 26.08, 'heartRate': 55.0, 'glucose': 66.0, 'TenYearCHD': 0}
# 105 ,{'_id': ObjectId('67864ff437f5a75d634d22c9'), 'id': 105, 'age': 60, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 222.0, 'sysBP': 118.0, 'diaBP': 73.0, 'BMI': 24.48, 'heartRate': 75.0, 'glucose': 90.0, 'TenYearCHD': 0}
# 106 ,{'_id': ObjectId('67864ff437f5a75d634d22ca'), 'id': 106, 'age': 46, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 15.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 247.0, 'sysBP': 125.0, 'diaBP': 80.0, 'BMI': 21.51, 'heartRate': 60.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 107 ,{'_id': ObjectId('67864ff437f5a75d634d22cb'), 'id': 107, 'age': 45, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 1, 'totChol': 189.0, 'sysBP': 132.0, 'diaBP': 78.0, 'BMI': 28.4, 'heartRate': 75.0, 'glucose': 177.0, 'TenYearCHD': 0}
# 108 ,{'_id': ObjectId('67864ff437f5a75d634d22cc'), 'id': 108, 'age': 49, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 288.0, 'sysBP': 128.0, 'diaBP': 89.0, 'BMI': 35.96, 'heartRate': 73.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 109 ,{'_id': ObjectId('67864ff437f5a75d634d22cd'), 'id': 109, 'age': 42, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 173.0, 'sysBP': 100.0, 'diaBP': 63.0, 'BMI': 23.25, 'heartRate': 65.0, 'glucose': 99.0, 'TenYearCHD': 0}
# 110 ,{'_id': ObjectId('67864ff437f5a75d634d22ce'), 'id': 110, 'age': 42, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 9.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 281.0, 'sysBP': 115.5, 'diaBP': 79.0, 'BMI': 22.9, 'heartRate': 80.0, 'glucose': 71.0, 'TenYearCHD': 0}
# 111 ,{'_id': ObjectId('67864ff437f5a75d634d22cf'), 'id': 111, 'age': 45, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 250.0, 'sysBP': 130.0, 'diaBP': 80.0, 'BMI': 20.24, 'heartRate': 90.0, 'glucose': 86.0, 'TenYearCHD': 0}
# 112 ,{'_id': ObjectId('67864ff437f5a75d634d22d0'), 'id': 112, 'age': 57, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 382.0, 'sysBP': 133.0, 'diaBP': 77.0, 'BMI': 24.27, 'heartRate': 75.0, 'glucose': 81.0, 'TenYearCHD': 0}
# 113 ,{'_id': ObjectId('67864ff437f5a75d634d22d1'), 'id': 113, 'age': 41, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 181.0, 'sysBP': 125.0, 'diaBP': 79.0, 'BMI': 19.09, 'heartRate': 60.0, 'glucose': 70.0, 'TenYearCHD': 0}
# 114 ,{'_id': ObjectId('67864ff437f5a75d634d22d2'), 'id': 114, 'age': 40, 'education': 4.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 200.0, 'sysBP': 116.0, 'diaBP': 69.0, 'BMI': 23.9, 'heartRate': 75.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 115 ,{'_id': ObjectId('67864ff437f5a75d634d22d3'), 'id': 115, 'age': 52, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 244.0, 'sysBP': 127.5, 'diaBP': 72.5, 'BMI': 24.29, 'heartRate': 67.0, 'glucose': 118.0, 'TenYearCHD': 0}
# 116 ,{'_id': ObjectId('67864ff437f5a75d634d22d4'), 'id': 116, 'age': 39, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 213.0, 'sysBP': 125.0, 'diaBP': 87.0, 'BMI': 16.73, 'heartRate': 110.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 117 ,{'_id': ObjectId('67864ff437f5a75d634d22d5'), 'id': 117, 'age': 45, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 232.0, 'sysBP': 122.5, 'diaBP': 82.5, 'BMI': 27.55, 'heartRate': 74.0, 'glucose': 59.0, 'TenYearCHD': 1}
# 118 ,{'_id': ObjectId('67864ff437f5a75d634d22d6'), 'id': 118, 'age': 48, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 17.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 218.0, 'sysBP': 113.0, 'diaBP': 79.0, 'BMI': 27.33, 'heartRate': 62.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 119 ,{'_id': ObjectId('67864ff437f5a75d634d22d7'), 'id': 119, 'age': 64, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 213.0, 'sysBP': 133.0, 'diaBP': 77.5, 'BMI': 35.62, 'heartRate': 77.0, 'glucose': 74.0, 'TenYearCHD': 0}
# 120 ,{'_id': ObjectId('67864ff437f5a75d634d22d8'), 'id': 120, 'age': 65, 'education': nan, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 221.0, 'sysBP': 155.0, 'diaBP': 92.0, 'BMI': 31.34, 'heartRate': 58.0, 'glucose': nan, 'TenYearCHD': 0}
# 121 ,{'_id': ObjectId('67864ff437f5a75d634d22d9'), 'id': 121, 'age': 64, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 273.0, 'sysBP': 123.0, 'diaBP': 73.5, 'BMI': 22.3, 'heartRate': 75.0, 'glucose': 84.0, 'TenYearCHD': 1}
# 122 ,{'_id': ObjectId('67864ff437f5a75d634d22da'), 'id': 122, 'age': 61, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 270.0, 'sysBP': 174.5, 'diaBP': 101.5, 'BMI': 29.87, 'heartRate': 80.0, 'glucose': 76.0, 'TenYearCHD': 0}
# 123 ,{'_id': ObjectId('67864ff437f5a75d634d22db'), 'id': 123, 'age': 36, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 188.0, 'sysBP': 112.0, 'diaBP': 78.0, 'BMI': 22.54, 'heartRate': 63.0, 'glucose': 73.0, 'TenYearCHD': 0}
# 124 ,{'_id': ObjectId('67864ff437f5a75d634d22dc'), 'id': 124, 'age': 45, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 195.0, 'sysBP': 129.5, 'diaBP': 83.0, 'BMI': 25.74, 'heartRate': 77.0, 'glucose': 74.0, 'TenYearCHD': 0}
# 125 ,{'_id': ObjectId('67864ff437f5a75d634d22dd'), 'id': 125, 'age': 60, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 266.0, 'sysBP': 135.0, 'diaBP': 87.0, 'BMI': 26.72, 'heartRate': 75.0, 'glucose': 82.0, 'TenYearCHD': 0}
# 126 ,{'_id': ObjectId('67864ff437f5a75d634d22de'), 'id': 126, 'age': 45, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 25.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 232.0, 'sysBP': 165.0, 'diaBP': 86.0, 'BMI': 23.86, 'heartRate': 78.0, 'glucose': 68.0, 'TenYearCHD': 0}
# 127 ,{'_id': ObjectId('67864ff437f5a75d634d22df'), 'id': 127, 'age': 57, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 15.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 221.0, 'sysBP': 117.0, 'diaBP': 72.0, 'BMI': 25.51, 'heartRate': 75.0, 'glucose': 83.0, 'TenYearCHD': 1}
# 128 ,{'_id': ObjectId('67864ff437f5a75d634d22e0'), 'id': 128, 'age': 67, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': nan, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 261.0, 'sysBP': 117.0, 'diaBP': 63.0, 'BMI': 22.55, 'heartRate': 75.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 129 ,{'_id': ObjectId('67864ff437f5a75d634d22e1'), 'id': 129, 'age': 62, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 214.0, 'sysBP': 110.0, 'diaBP': 62.5, 'BMI': 23.8, 'heartRate': 77.0, 'glucose': 95.0, 'TenYearCHD': 1}
# 130 ,{'_id': ObjectId('67864ff437f5a75d634d22e2'), 'id': 130, 'age': 63, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 1, 'totChol': 229.0, 'sysBP': 109.0, 'diaBP': 75.0, 'BMI': 38.42, 'heartRate': 110.0, 'glucose': 120.0, 'TenYearCHD': 0}
# 131 ,{'_id': ObjectId('67864ff437f5a75d634d22e3'), 'id': 131, 'age': 47, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 200.0, 'sysBP': 126.0, 'diaBP': 86.0, 'BMI': 26.84, 'heartRate': 80.0, 'glucose': 96.0, 'TenYearCHD': 0}
# 132 ,{'_id': ObjectId('67864ff437f5a75d634d22e4'), 'id': 132, 'age': 48, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 10.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 268.0, 'sysBP': 117.5, 'diaBP': 80.0, 'BMI': 36.11, 'heartRate': 72.0, 'glucose': 67.0, 'TenYearCHD': 0}
# 133 ,{'_id': ObjectId('67864ff437f5a75d634d22e5'), 'id': 133, 'age': 61, 'education': nan, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 5.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 175.0, 'sysBP': 134.0, 'diaBP': 82.5, 'BMI': 18.59, 'heartRate': 72.0, 'glucose': 75.0, 'TenYearCHD': 1}
# 134 ,{'_id': ObjectId('67864ff437f5a75d634d22e6'), 'id': 134, 'age': 64, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 1, 'totChol': 262.0, 'sysBP': 147.0, 'diaBP': 90.0, 'BMI': 26.51, 'heartRate': 85.0, 'glucose': 173.0, 'TenYearCHD': 0}
# 135 ,{'_id': ObjectId('67864ff437f5a75d634d22e7'), 'id': 135, 'age': 63, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 235.0, 'sysBP': 125.0, 'diaBP': 79.0, 'BMI': 24.38, 'heartRate': 96.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 136 ,{'_id': ObjectId('67864ff437f5a75d634d22e8'), 'id': 136, 'age': 38, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 174.0, 'sysBP': 101.0, 'diaBP': 68.0, 'BMI': 27.47, 'heartRate': 85.0, 'glucose': nan, 'TenYearCHD': 0}
# 137 ,{'_id': ObjectId('67864ff437f5a75d634d22e9'), 'id': 137, 'age': 39, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 43.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 291.0, 'sysBP': 177.5, 'diaBP': 100.0, 'BMI': 25.74, 'heartRate': 67.0, 'glucose': 91.0, 'TenYearCHD': 0}
# 138 ,{'_id': ObjectId('67864ff437f5a75d634d22ea'), 'id': 138, 'age': 53, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 238.0, 'sysBP': 172.5, 'diaBP': 91.0, 'BMI': 24.16, 'heartRate': 112.0, 'glucose': nan, 'TenYearCHD': 0}
# 139 ,{'_id': ObjectId('67864ff437f5a75d634d22eb'), 'id': 139, 'age': 50, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 312.0, 'sysBP': 125.0, 'diaBP': 85.0, 'BMI': 27.07, 'heartRate': 88.0, 'glucose': 94.0, 'TenYearCHD': 0}
# 140 ,{'_id': ObjectId('67864ff437f5a75d634d22ec'), 'id': 140, 'age': 45, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 5.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 170.0, 'sysBP': 109.5, 'diaBP': 69.0, 'BMI': 17.38, 'heartRate': 88.0, 'glucose': 66.0, 'TenYearCHD': 0}
# 141 ,{'_id': ObjectId('67864ff437f5a75d634d22ed'), 'id': 141, 'age': 57, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 176.0, 'sysBP': 134.0, 'diaBP': 97.0, 'BMI': 38.14, 'heartRate': 68.0, 'glucose': 94.0, 'TenYearCHD': 0}
# 142 ,{'_id': ObjectId('67864ff437f5a75d634d22ee'), 'id': 142, 'age': 67, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 326.0, 'sysBP': 157.5, 'diaBP': 78.0, 'BMI': 24.63, 'heartRate': 85.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 143 ,{'_id': ObjectId('67864ff437f5a75d634d22ef'), 'id': 143, 'age': 55, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 257.0, 'sysBP': 132.0, 'diaBP': 81.0, 'BMI': 27.49, 'heartRate': 60.0, 'glucose': 86.0, 'TenYearCHD': 0}
# 144 ,{'_id': ObjectId('67864ff437f5a75d634d22f0'), 'id': 144, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 193.0, 'sysBP': 118.0, 'diaBP': 92.0, 'BMI': 21.14, 'heartRate': 75.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 145 ,{'_id': ObjectId('67864ff437f5a75d634d22f1'), 'id': 145, 'age': 40, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 290.0, 'sysBP': 120.0, 'diaBP': 89.0, 'BMI': 27.99, 'heartRate': 80.0, 'glucose': 66.0, 'TenYearCHD': 0}
# ...
# 3342 ,{'_id': ObjectId('67864ff437f5a75d634d2f6e'), 'id': 3342, 'age': 39, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 214.0, 'sysBP': 123.0, 'diaBP': 78.0, 'BMI': 38.06, 'heartRate': 66.0, 'glucose': 62.0, 'TenYearCHD': 0}
# 3343 ,{'_id': ObjectId('67864ff437f5a75d634d2f6f'), 'id': 3343, 'age': 55, 'education': 4.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 260.0, 'sysBP': 172.5, 'diaBP': 100.5, 'BMI': 32.27, 'heartRate': 58.0, 'glucose': 72.0, 'TenYearCHD': 1}
# 3344 ,{'_id': ObjectId('67864ff437f5a75d634d2f70'), 'id': 3344, 'age': 62, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 263.0, 'sysBP': 112.0, 'diaBP': 61.0, 'BMI': 24.46, 'heartRate': 68.0, 'glucose': 95.0, 'TenYearCHD': 0}
# 3345 ,{'_id': ObjectId('67864ff437f5a75d634d2f71'), 'id': 3345, 'age': 54, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 195.0, 'sysBP': 132.0, 'diaBP': 83.5, 'BMI': 26.21, 'heartRate': 75.0, 'glucose': 100.0, 'TenYearCHD': 0}
# 3346 ,{'_id': ObjectId('67864ff437f5a75d634d2f72'), 'id': 3346, 'age': 57, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 249.0, 'sysBP': 139.0, 'diaBP': 83.0, 'BMI': 23.81, 'heartRate': 85.0, 'glucose': 76.0, 'TenYearCHD': 0}
# 3347 ,{'_id': ObjectId('67864ff437f5a75d634d2f73'), 'id': 3347, 'age': 63, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 233.0, 'sysBP': 130.0, 'diaBP': 81.0, 'BMI': 25.82, 'heartRate': 80.0, 'glucose': 81.0, 'TenYearCHD': 0}
# 3348 ,{'_id': ObjectId('67864ff437f5a75d634d2f74'), 'id': 3348, 'age': 53, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 240.0, 'sysBP': 174.5, 'diaBP': 103.0, 'BMI': 29.82, 'heartRate': 81.0, 'glucose': 74.0, 'TenYearCHD': 1}
# 3349 ,{'_id': ObjectId('67864ff437f5a75d634d2f75'), 'id': 3349, 'age': 46, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 242.0, 'sysBP': 129.0, 'diaBP': 85.0, 'BMI': 27.4, 'heartRate': 80.0, 'glucose': nan, 'TenYearCHD': 1}
# 3350 ,{'_id': ObjectId('67864ff437f5a75d634d2f76'), 'id': 3350, 'age': 52, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 266.0, 'sysBP': 117.0, 'diaBP': 78.0, 'BMI': 27.39, 'heartRate': 70.0, 'glucose': 88.0, 'TenYearCHD': 0}
# 3351 ,{'_id': ObjectId('67864ff437f5a75d634d2f77'), 'id': 3351, 'age': 57, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 235.0, 'sysBP': 123.0, 'diaBP': 78.0, 'BMI': 28.53, 'heartRate': 60.0, 'glucose': 74.0, 'TenYearCHD': 0}
# 3352 ,{'_id': ObjectId('67864ff437f5a75d634d2f78'), 'id': 3352, 'age': 39, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 258.0, 'sysBP': 110.0, 'diaBP': 65.0, 'BMI': 19.97, 'heartRate': 65.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 3353 ,{'_id': ObjectId('67864ff437f5a75d634d2f79'), 'id': 3353, 'age': 50, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 258.0, 'sysBP': 144.0, 'diaBP': 88.0, 'BMI': 24.19, 'heartRate': 100.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 3354 ,{'_id': ObjectId('67864ff437f5a75d634d2f7a'), 'id': 3354, 'age': 38, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 1, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 224.0, 'sysBP': 127.5, 'diaBP': 81.0, 'BMI': 20.39, 'heartRate': 80.0, 'glucose': 90.0, 'TenYearCHD': 0}
# 3355 ,{'_id': ObjectId('67864ff437f5a75d634d2f7b'), 'id': 3355, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 254.0, 'sysBP': 136.0, 'diaBP': 87.0, 'BMI': 31.24, 'heartRate': 88.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 3356 ,{'_id': ObjectId('67864ff437f5a75d634d2f7c'), 'id': 3356, 'age': 38, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 171.0, 'sysBP': 110.0, 'diaBP': 71.0, 'BMI': 21.8, 'heartRate': 82.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 3357 ,{'_id': ObjectId('67864ff437f5a75d634d2f7d'), 'id': 3357, 'age': 44, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 216.0, 'sysBP': 113.5, 'diaBP': 77.0, 'BMI': 28.23, 'heartRate': 64.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 3358 ,{'_id': ObjectId('67864ff437f5a75d634d2f7e'), 'id': 3358, 'age': 53, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 228.0, 'sysBP': 114.0, 'diaBP': 80.0, 'BMI': 20.54, 'heartRate': 55.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 3359 ,{'_id': ObjectId('67864ff437f5a75d634d2f7f'), 'id': 3359, 'age': 56, 'education': 3.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 177.0, 'sysBP': 124.0, 'diaBP': 77.0, 'BMI': 27.81, 'heartRate': 60.0, 'glucose': 88.0, 'TenYearCHD': 0}
# 3360 ,{'_id': ObjectId('67864ff437f5a75d634d2f80'), 'id': 3360, 'age': 56, 'education': 2.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 241.0, 'sysBP': 130.0, 'diaBP': 85.0, 'BMI': 25.79, 'heartRate': 68.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 3361 ,{'_id': ObjectId('67864ff437f5a75d634d2f81'), 'id': 3361, 'age': 42, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 230.0, 'sysBP': 142.5, 'diaBP': 97.5, 'BMI': 29.94, 'heartRate': 75.0, 'glucose': 75.0, 'TenYearCHD': 0}
# 3362 ,{'_id': ObjectId('67864ff437f5a75d634d2f82'), 'id': 3362, 'age': 48, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 206.0, 'sysBP': 118.0, 'diaBP': 81.0, 'BMI': 28.13, 'heartRate': 72.0, 'glucose': 87.0, 'TenYearCHD': 0}
# 3363 ,{'_id': ObjectId('67864ff437f5a75d634d2f83'), 'id': 3363, 'age': 45, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 23.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 263.0, 'sysBP': 115.0, 'diaBP': 76.0, 'BMI': 24.94, 'heartRate': 68.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 3364 ,{'_id': ObjectId('67864ff437f5a75d634d2f84'), 'id': 3364, 'age': 62, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 268.0, 'sysBP': 143.5, 'diaBP': 90.0, 'BMI': 29.64, 'heartRate': 88.0, 'glucose': 83.0, 'TenYearCHD': 0}
# 3365 ,{'_id': ObjectId('67864ff437f5a75d634d2f85'), 'id': 3365, 'age': 55, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 310.0, 'sysBP': 135.0, 'diaBP': 76.5, 'BMI': 26.31, 'heartRate': 110.0, 'glucose': 74.0, 'TenYearCHD': 0}
# 3366 ,{'_id': ObjectId('67864ff437f5a75d634d2f86'), 'id': 3366, 'age': 43, 'education': 4.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 201.0, 'sysBP': 129.0, 'diaBP': 92.0, 'BMI': 24.54, 'heartRate': 88.0, 'glucose': 63.0, 'TenYearCHD': 0}
# 3367 ,{'_id': ObjectId('67864ff437f5a75d634d2f87'), 'id': 3367, 'age': 59, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 206.0, 'sysBP': 187.0, 'diaBP': 97.0, 'BMI': 26.0, 'heartRate': 100.0, 'glucose': 69.0, 'TenYearCHD': 0}
# 3368 ,{'_id': ObjectId('67864ff437f5a75d634d2f88'), 'id': 3368, 'age': 40, 'education': 4.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 25.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 258.0, 'sysBP': 112.0, 'diaBP': 78.0, 'BMI': 28.57, 'heartRate': 80.0, 'glucose': 70.0, 'TenYearCHD': 0}
# 3369 ,{'_id': ObjectId('67864ff437f5a75d634d2f89'), 'id': 3369, 'age': 44, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 5.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 205.0, 'sysBP': 120.0, 'diaBP': 83.5, 'BMI': 24.3, 'heartRate': 67.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 3370 ,{'_id': ObjectId('67864ff437f5a75d634d2f8a'), 'id': 3370, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 219.0, 'sysBP': 107.0, 'diaBP': 69.0, 'BMI': 21.4, 'heartRate': 66.0, 'glucose': nan, 'TenYearCHD': 0}
# 3371 ,{'_id': ObjectId('67864ff437f5a75d634d2f8b'), 'id': 3371, 'age': 55, 'education': 2.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 1.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 285.0, 'sysBP': 158.0, 'diaBP': 98.0, 'BMI': 30.23, 'heartRate': 70.0, 'glucose': 88.0, 'TenYearCHD': 0}
# 3372 ,{'_id': ObjectId('67864ff437f5a75d634d2f8c'), 'id': 3372, 'age': 43, 'education': 2.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 276.0, 'sysBP': 99.0, 'diaBP': 62.0, 'BMI': 22.17, 'heartRate': 60.0, 'glucose': 80.0, 'TenYearCHD': 0}
# 3373 ,{'_id': ObjectId('67864ff437f5a75d634d2f8d'), 'id': 3373, 'age': 58, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 1, 'totChol': 260.0, 'sysBP': 85.5, 'diaBP': 51.0, 'BMI': 20.76, 'heartRate': 87.0, 'glucose': 206.0, 'TenYearCHD': 1}
# 3374 ,{'_id': ObjectId('67864ff437f5a75d634d2f8e'), 'id': 3374, 'age': 67, 'education': 2.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 60.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 261.0, 'sysBP': 170.0, 'diaBP': 100.0, 'BMI': 22.71, 'heartRate': 72.0, 'glucose': 79.0, 'TenYearCHD': 1}
# 3375 ,{'_id': ObjectId('67864ff437f5a75d634d2f8f'), 'id': 3375, 'age': 52, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 200.0, 'sysBP': 141.0, 'diaBP': 81.5, 'BMI': 26.56, 'heartRate': 70.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 3376 ,{'_id': ObjectId('67864ff437f5a75d634d2f90'), 'id': 3376, 'age': 52, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 220.0, 'sysBP': 163.0, 'diaBP': 87.0, 'BMI': 25.12, 'heartRate': 100.0, 'glucose': 94.0, 'TenYearCHD': 0}
# 3377 ,{'_id': ObjectId('67864ff437f5a75d634d2f91'), 'id': 3377, 'age': 37, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 25.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 243.0, 'sysBP': 125.0, 'diaBP': 75.0, 'BMI': 29.19, 'heartRate': 60.0, 'glucose': 78.0, 'TenYearCHD': 0}
# 3378 ,{'_id': ObjectId('67864ff437f5a75d634d2f92'), 'id': 3378, 'age': 39, 'education': 3.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': nan, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 197.0, 'sysBP': 126.5, 'diaBP': 76.5, 'BMI': 19.71, 'heartRate': 55.0, 'glucose': 63.0, 'TenYearCHD': 0}
# 3379 ,{'_id': ObjectId('67864ff437f5a75d634d2f93'), 'id': 3379, 'age': 39, 'education': 1.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 30.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 292.0, 'sysBP': 120.0, 'diaBP': 85.0, 'BMI': 31.09, 'heartRate': 85.0, 'glucose': nan, 'TenYearCHD': 0}
# 3380 ,{'_id': ObjectId('67864ff437f5a75d634d2f94'), 'id': 3380, 'age': 56, 'education': 1.0, 'sex': 'F', 'is_smoking': 'YES', 'cigsPerDay': 20.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 240.0, 'sysBP': 125.0, 'diaBP': 79.0, 'BMI': 27.38, 'heartRate': 80.0, 'glucose': 82.0, 'TenYearCHD': 0}
# 3381 ,{'_id': ObjectId('67864ff437f5a75d634d2f95'), 'id': 3381, 'age': 63, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 205.0, 'sysBP': 138.0, 'diaBP': 71.0, 'BMI': 33.11, 'heartRate': 60.0, 'glucose': 85.0, 'TenYearCHD': 1}
# 3382 ,{'_id': ObjectId('67864ff437f5a75d634d2f96'), 'id': 3382, 'age': 43, 'education': 4.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 260.0, 'sysBP': 129.0, 'diaBP': 90.0, 'BMI': 25.29, 'heartRate': 70.0, 'glucose': 62.0, 'TenYearCHD': 0}
# 3383 ,{'_id': ObjectId('67864ff437f5a75d634d2f97'), 'id': 3383, 'age': 57, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 210.0, 'sysBP': 131.0, 'diaBP': 85.0, 'BMI': 26.59, 'heartRate': 70.0, 'glucose': 77.0, 'TenYearCHD': 0}
# 3384 ,{'_id': ObjectId('67864ff437f5a75d634d2f98'), 'id': 3384, 'age': 61, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 217.0, 'sysBP': 182.0, 'diaBP': 86.0, 'BMI': 26.98, 'heartRate': 105.0, 'glucose': 113.0, 'TenYearCHD': 0}
# 3385 ,{'_id': ObjectId('67864ff437f5a75d634d2f99'), 'id': 3385, 'age': 60, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 261.0, 'sysBP': 123.5, 'diaBP': 79.0, 'BMI': 29.28, 'heartRate': 70.0, 'glucose': 103.0, 'TenYearCHD': 0}
# 3386 ,{'_id': ObjectId('67864ff437f5a75d634d2f9a'), 'id': 3386, 'age': 46, 'education': 1.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 199.0, 'sysBP': 102.0, 'diaBP': 56.0, 'BMI': 21.96, 'heartRate': 80.0, 'glucose': 84.0, 'TenYearCHD': 0}
# 3387 ,{'_id': ObjectId('67864ff437f5a75d634d2f9b'), 'id': 3387, 'age': 44, 'education': 3.0, 'sex': 'M', 'is_smoking': 'YES', 'cigsPerDay': 3.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 352.0, 'sysBP': 164.0, 'diaBP': 119.0, 'BMI': 28.92, 'heartRate': 73.0, 'glucose': 72.0, 'TenYearCHD': 1}
# 3388 ,{'_id': ObjectId('67864ff437f5a75d634d2f9c'), 'id': 3388, 'age': 60, 'education': 1.0, 'sex': 'M', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': nan, 'prevalentStroke': 0, 'prevalentHyp': 1, 'diabetes': 0, 'totChol': 191.0, 'sysBP': 167.0, 'diaBP': 105.0, 'BMI': 23.01, 'heartRate': 80.0, 'glucose': 85.0, 'TenYearCHD': 0}
# 3389 ,{'_id': ObjectId('67864ff437f5a75d634d2f9d'), 'id': 3389, 'age': 54, 'education': 3.0, 'sex': 'F', 'is_smoking': 'NO', 'cigsPerDay': 0.0, 'BPMeds': 0.0, 'prevalentStroke': 0, 'prevalentHyp': 0, 'diabetes': 0, 'totChol': 288.0, 'sysBP': 124.0, 'diaBP': 77.0, 'BMI': 29.88, 'heartRate': 79.0, 'glucose': 92.0, 'TenYearCHD': 0}

# %%
if "_id" in df.columns.to_list():
    df=df.drop(columns='_id' ,axis=1)

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
from evidently.model_profile import Profile
from evidently.model_profile.sections import DataDriftProfileSection
# Out:
# c:\Users\kumar\anaconda3\envs\cardeo\lib\site-packages\evidently\analyzers\__init__.py:3: UserWarning: analyzers are deprecated, use metrics instead
#   warnings.warn("analyzers are deprecated, use metrics instead")
# c:\Users\kumar\anaconda3\envs\cardeo\lib\site-packages\evidently\model_profile\__init__.py:8: UserWarning: model profiles are deprecated, use metrics instead
#   warnings.warn("model profiles are deprecated, use metrics instead")

# %%
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

# %%
data_drift_report = Report(metrics=[
    DataDriftPreset(),
])

data_drift_report.run(current_data=iris_frame.iloc[:60], reference_data=iris_frame.iloc[60:], column_mapping=None)
data_drift_report

# %%
import logging

# %%
logging.basicConfig(
    level=logging.INFO,  # Set the logging level (DEBUG, INFO, WARNING, ERROR, CRITICAL)
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("app.log"),  # Log messages to a file
        logging.StreamHandler()         # Display messages in the console
    ]
)

# %%
logging.info("iam laxman")
# Out:
# 2025-01-16 21:15:37,182 - root - INFO - iam laxman
